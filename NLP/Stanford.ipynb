# %%
import stanfordnlp

# %%
import pandas as pd

# %% [markdown]
# Run this once:

# %%
stanfordnlp.download('en')
# Out:
# Using the default treebank "en_ewt" for language "en".
# Would you like to download the models for: en_ewt now? (Y/n)
# Y
#
# Default download directory: C:\Users\febrah1\stanfordnlp_resources
# Hit enter to continue or type an alternate directory.
#
#
# Downloading models for: en_ewt
# Download location: C:\Users\febrah1\stanfordnlp_resources\en_ewt_models.zip
# 100%|███████████████████████████████████████████████████████████████████████████████| 235M/235M [00:39<00:00, 5.38MB/s]
# Download complete.  Models saved to: C:\Users\febrah1\stanfordnlp_resources\en_ewt_models.zip
# Extracting models file for: en_ewt
# Cleaning up...Done.

# %%
nlp = stanfordnlp.Pipeline()
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': 'C:\\Users\\febrah1\\stanfordnlp_resources\\en_ewt_models\\en_ewt_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': 'C:\\Users\\febrah1\\stanfordnlp_resources\\en_ewt_models\\en_ewt_tagger.pt', 'pretrain_path': 'C:\\Users\\febrah1\\stanfordnlp_resources\\en_ewt_models\\en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': 'C:\\Users\\febrah1\\stanfordnlp_resources\\en_ewt_models\\en_ewt_lemmatizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': 'C:\\Users\\febrah1\\stanfordnlp_resources\\en_ewt_models\\en_ewt_parser.pt', 'pretrain_path': 'C:\\Users\\febrah1\\stanfordnlp_resources\\en_ewt_models\\en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---

# %%
with open('pubMed_truncated.txt', 'r') as file:
    data = file.read().replace('\n', '')

# %%
doc = nlp(data)

# %%
for sentence in doc.sentences:
    sentence.print_dependencies()
# Out:
# ('A', '4', 'det')
# ('novel', '3', 'compound')
# ('missense', '4', 'compound')
# ('mutation', '7', 'compound')
# ('Asp', '7', 'compound')
# ('506', '5', 'nummod')
# ('Gly', '0', 'root')
# ('in', '9', 'case')
# ('Exon', '7', 'nmod')
# ('13', '9', 'nummod')
# ('of', '14', 'case')
# ('the', '14', 'det')
# ('F11', '14', 'compound')
# ('gene', '7', 'nmod')
# ('in', '19', 'case')
# ('an', '19', 'det')
# ('asymptomatic', '19', 'amod')
# ('Korean', '19', 'amod')
# ('woman', '7', 'nmod')
# ('with', '24', 'case')
# ('mild', '24', 'amod')
# ('factor', '24', 'compound')
# ('XI', '24', 'compound')
# ('deficiency', '19', 'nmod')
# ('.', '7', 'punct')
# ('Factor', '2', 'compound')
# ('XI', '13', 'nsubj')
# ('(', '4', 'punct')
# ('FXI', '2', 'appos')
# (')', '4', 'punct')
# ('deficiency', '13', 'nsubj')
# ('is', '13', 'cop')
# ('a', '13', 'det')
# ('rare', '13', 'amod')
# ('autosomal', '13', 'amod')
# ('recessive', '13', 'amod')
# ('coagulation', '13', 'compound')
# ('disorder', '0', 'root')
# ('most', '15', 'advmod')
# ('commonly', '16', 'advmod')
# ('found', '13', 'acl')
# ('in', '18', 'case')
# ('Ashkenazi', '16', 'obl')
# ('and', '21', 'cc')
# ('Iraqi', '21', 'amod')
# ('Jews', '18', 'conj')
# (',', '27', 'punct')
# ('but', '27', 'cc')
# ('it', '27', 'nsubj:pass')
# ('is', '27', 'aux:pass')
# ('also', '27', 'advmod')
# ('found', '13', 'conj')
# ('in', '31', 'case')
# ('other', '31', 'amod')
# ('ethnic', '31', 'amod')
# ('groups', '27', 'obl')
# ('.', '13', 'punct')
# ('It', '4', 'nsubj')
# ('is', '4', 'cop')
# ('a', '4', 'det')
# ('trauma', '0', 'root')
# ('or', '10', 'cc')
# ('surgery', '8', 'obl:npmod')
# ('-', '8', 'punct')
# ('related', '10', 'amod')
# ('bleeding', '10', 'compound')
# ('disorder', '4', 'conj')
# (',', '17', 'punct')
# ('but', '17', 'cc')
# ('spontaneous', '14', 'amod')
# ('bleeding', '17', 'nsubj:pass')
# ('is', '17', 'aux:pass')
# ('rarely', '17', 'advmod')
# ('seen', '4', 'conj')
# ('.', '4', 'punct')
# ('The', '3', 'det')
# ('clinical', '3', 'amod')
# ('manifestation', '11', 'nsubj')
# ('of', '5', 'mark')
# ('bleeding', '3', 'acl')
# ('in', '9', 'case')
# ('FXI', '9', 'compound')
# ('deficiency', '9', 'compound')
# ('cases', '5', 'obl')
# ('is', '11', 'cop')
# ('variable', '0', 'root')
# ('and', '13', 'cc')
# ('seems', '11', 'conj')
# ('to', '16', 'mark')
# ('poorly', '16', 'advmod')
# ('correlate', '13', 'xcomp')
# ('with', '20', 'case')
# ('plasma', '20', 'compound')
# ('FXI', '20', 'compound')
# ('levels', '16', 'obl')
# ('.', '11', 'punct')
# ('The', '3', 'det')
# ('molecular', '3', 'amod')
# ('pathology', '8', 'nsubj')
# ('of', '6', 'case')
# ('FXI', '6', 'compound')
# ('deficiency', '3', 'nmod')
# ('is', '8', 'cop')
# ('mutation', '0', 'root')
# ('in', '12', 'case')
# ('the', '12', 'det')
# ('F11', '12', 'compound')
# ('gene', '8', 'nmod')
# ('on', '16', 'case')
# ('the', '16', 'det')
# ('chromosome', '16', 'compound')
# ('band', '12', 'nmod')
# ('4q35', '16', 'nummod')
# ('.', '8', 'punct')
# ('We', '2', 'nsubj')
# ('report', '0', 'root')
# ('a', '5', 'det')
# ('novel', '5', 'compound')
# ('mutation', '2', 'obj')
# ('of', '9', 'case')
# ('the', '9', 'det')
# ('F11', '9', 'compound')
# ('gene', '5', 'nmod')
# ('in', '19', 'case')
# ('an', '19', 'det')
# ('18', '14', 'nummod')
# ('-', '14', 'punct')
# ('year', '16', 'obl:npmod')
# ('-', '16', 'punct')
# ('old', '19', 'amod')
# ('asymptomatic', '19', 'amod')
# ('Korean', '19', 'amod')
# ('woman', '5', 'nmod')
# ('with', '23', 'case')
# ('mild', '23', 'amod')
# ('FXI', '23', 'compound')
# ('deficiency', '19', 'nmod')
# ('.', '2', 'punct')
# ('Pre-operative', '4', 'amod')
# ('laboratory', '3', 'compound')
# ('screen', '4', 'compound')
# ('tests', '10', 'nsubj')
# ('for', '6', 'case')
# ('lipoma', '4', 'nmod')
# ('on', '9', 'case')
# ('her', '9', 'nmod:poss')
# ('back', '6', 'nmod')
# ('revealed', '0', 'root')
# ('slightly', '12', 'advmod')
# ('prolonged', '10', 'xcomp')
# ('activated', '16', 'amod')
# ('partial', '16', 'amod')
# ('thromboplastin', '16', 'compound')
# ('time', '10', 'obj')
# ('(', '19', 'punct')
# ('45.2', '19', 'nummod')
# ('sec', '16', 'appos')
# (';', '19', 'punct')
# ('reference', '22', 'compound')
# ('range', '16', 'appos')
# (',', '22', 'punct')
# ('23.2-39.4', '25', 'nummod')
# ('sec', '16', 'appos')
# (')', '25', 'punct')
# ('.', '10', 'punct')
# ('Her', '3', 'nmod:poss')
# ('FXI', '3', 'compound')
# ('activity', '10', 'nsubj')
# ('(', '6', 'punct')
# ('35', '6', 'nummod')
# ('%', '3', 'appos')
# (')', '6', 'punct')
# ('was', '10', 'cop')
# ('slightly', '10', 'advmod')
# ('lower', '0', 'root')
# ('than', '15', 'case')
# ('the', '15', 'det')
# ('normal', '15', 'amod')
# ('FXI', '15', 'compound')
# ('activity', '10', 'obl')
# ('(', '18', 'punct')
# ('reference', '18', 'compound')
# ('range', '15', 'appos')
# (',', '18', 'punct')
# ('50', '23', 'nummod')
# ('-', '22', 'case')
# ('150', '20', 'nmod')
# ('%', '18', 'appos')
# (')', '18', 'punct')
# ('.', '10', 'punct')
# ('Direct', '3', 'amod')
# ('sequence', '3', 'compound')
# ('analysis', '8', 'nsubj')
# ('of', '7', 'case')
# ('the', '7', 'det')
# ('F11', '7', 'compound')
# ('gene', '3', 'nmod')
# ('revealed', '0', 'root')
# ('a', '14', 'det')
# ('heterozygous', '14', 'compound')
# ('A', '14', 'compound')
# ('to', '13', 'case')
# ('G', '11', 'nmod')
# ('substitution', '8', 'obj')
# ('in', '16', 'case')
# ('nucleotide', '8', 'obl')
# ('1517', '16', 'nummod')
# ('(', '19', 'punct')
# ('c.1517A', '16', 'appos')
# ('>', '19', 'punct')
# ('G', '19', 'nummod')
# (')', '19', 'punct')
# ('of', '24', 'case')
# ('exon', '8', 'obl')
# ('13', '24', 'nummod')
# (',', '8', 'punct')
# ('resulting', '8', 'advcl')
# ('in', '30', 'case')
# ('the', '30', 'det')
# ('substitution', '27', 'obl')
# ('of', '33', 'case')
# ('aspartic', '33', 'amod')
# ('acid', '30', 'nmod')
# ('with', '35', 'case')
# ('glycine', '30', 'nmod')
# ('in', '37', 'case')
# ('codon', '35', 'nmod')
# ('506', '37', 'nummod')
# ('(', '40', 'punct')
# ('p.', '37', 'appos')
# ('Asp', '40', 'compound')
# ('506', '43', 'nummod')
# ('Gly', '40', 'appos')
# (')', '40', 'punct')
# ('.', '8', 'punct')
# ('To', '3', 'case')
# ('the', '3', 'det')
# ('best', '14', 'obl')
# ('of', '6', 'case')
# ('our', '6', 'nmod:poss')
# ('knowledge', '3', 'nmod')
# (',', '14', 'punct')
# ('the', '9', 'det')
# ('Asp506Gly', '14', 'nsubj')
# ('is', '14', 'cop')
# ('a', '14', 'det')
# ('novel', '14', 'compound')
# ('missense', '14', 'compound')
# ('mutation', '0', 'root')
# (',', '23', 'punct')
# ('and', '23', 'cc')
# ('this', '23', 'nsubj')
# ('is', '23', 'cop')
# ('the', '23', 'det')
# ('first', '22', 'advmod')
# ('genetically', '22', 'advmod')
# ('confirmed', '23', 'amod')
# ('case', '14', 'conj')
# ('of', '27', 'case')
# ('mild', '27', 'amod')
# ('FXI', '27', 'compound')
# ('deficiency', '23', 'nmod')
# ('in', '29', 'case')
# ('Korea', '27', 'nmod')
# ('.', '14', 'punct')
# ('Mutations', '0', 'root')
# ('in', '5', 'case')
# ('mitochondrially', '4', 'advmod')
# ('encoded', '5', 'amod')
# ('complex', '1', 'nmod')
# ('I', '2', 'nsubj')
# ('enzyme', '0', 'root')
# ('as', '7', 'case')
# ('the', '7', 'det')
# ('second', '7', 'amod')
# ('common', '7', 'amod')
# ('cause', '2', 'obl')
# ('in', '10', 'case')
# ('a', '10', 'det')
# ('cohort', '7', 'nmod')
# ('of', '13', 'case')
# ('Chinese', '13', 'amod')
# ('patients', '10', 'nmod')
# ('with', '16', 'case')
# ('mitochondrial', '16', 'amod')
# ('myopathy', '10', 'nmod')
# (',', '18', 'punct')
# ('encephalopathy', '16', 'conj')
# (',', '21', 'punct')
# ('lactic', '21', 'compound')
# ('acidosis', '16', 'conj')
# ('and', '26', 'cc')
# ('stroke', '25', 'obl:npmod')
# ('-', '25', 'punct')
# ('like', '26', 'amod')
# ('episodes', '16', 'conj')
# ('.', '2', 'punct')
# ('The', '3', 'det')
# ('mutation', '3', 'compound')
# ('pattern', '33', 'nsubj:pass')
# ('of', '6', 'case')
# ('mitochondrial', '6', 'amod')
# ('DNA', '3', 'nmod')
# ('(', '8', 'punct')
# ('mtDNA', '6', 'appos')
# (')', '8', 'punct')
# ('in', '13', 'case')
# ('mainland', '13', 'compound')
# ('Chinese', '13', 'amod')
# ('patients', '3', 'nmod')
# ('with', '16', 'case')
# ('mitochondrial', '16', 'amod')
# ('myopathy', '13', 'nmod')
# (',', '18', 'punct')
# ('encephalopathy', '16', 'conj')
# (',', '21', 'punct')
# ('lactic', '21', 'compound')
# ('acidosis', '16', 'conj')
# ('and', '26', 'cc')
# ('stroke', '25', 'obl:npmod')
# ('-', '25', 'punct')
# ('like', '26', 'amod')
# ('episodes', '16', 'conj')
# ('(', '28', 'punct')
# ('MELAS', '26', 'appos')
# (')', '28', 'punct')
# ('has', '33', 'aux')
# ('been', '33', 'aux:pass')
# ('rarely', '33', 'advmod')
# ('reported', '0', 'root')
# (',', '33', 'punct')
# ('though', '38', 'mark')
# ('previous', '37', 'amod')
# ('data', '38', 'nsubj')
# ('suggested', '33', 'advcl')
# ('that', '47', 'mark')
# ('the', '42', 'det')
# ('mutation', '42', 'compound')
# ('pattern', '47', 'nsubj')
# ('of', '44', 'case')
# ('MELAS', '42', 'nmod')
# ('could', '47', 'aux')
# ('be', '47', 'cop')
# ('different', '38', 'ccomp')
# ('among', '51', 'case')
# ('geographically', '50', 'advmod')
# ('localized', '51', 'amod')
# ('populations', '47', 'obl')
# ('.', '33', 'punct')
# ('We', '2', 'nsubj')
# ('presented', '0', 'root')
# ('the', '4', 'det')
# ('results', '2', 'obj')
# ('of', '9', 'case')
# ('comprehensive', '9', 'amod')
# ('mtDNA', '8', 'compound')
# ('mutation', '9', 'compound')
# ('analysis', '4', 'nmod')
# ('in', '14', 'case')
# ('92', '14', 'nummod')
# ('unrelated', '14', 'amod')
# ('Chinese', '14', 'amod')
# ('patients', '4', 'nmod')
# ('with', '16', 'case')
# ('MELAS', '14', 'nmod')
# ('(', '18', 'punct')
# ('85', '14', 'appos')
# ('with', '21', 'case')
# ('classic', '21', 'amod')
# ('MELAS', '18', 'nmod')
# ('and', '23', 'cc')
# ('7', '21', 'conj')
# ('with', '28', 'case')
# ('MELAS', '28', 'compound')
# ('/', '27', 'cc')
# ('Leigh', '25', 'conj')
# ('syndrome', '21', 'conj')
# ('(', '30', 'punct')
# ('LS', '28', 'appos')
# (')', '30', 'punct')
# ('overlap', '33', 'amod')
# ('syndrome', '28', 'appos')
# (')', '33', 'punct')
# ('.', '2', 'punct')
# ('The', '4', 'det')
# ('mtDNA', '4', 'compound')
# ('A3243G', '4', 'compound')
# ('mutation', '10', 'nsubj')
# ('was', '10', 'cop')
# ('the', '10', 'det')
# ('most', '8', 'advmod')
# ('common', '10', 'amod')
# ('causal', '10', 'amod')
# ('genotype', '0', 'root')
# ('in', '14', 'case')
# ('this', '14', 'det')
# ('patient', '14', 'compound')
# ('group', '10', 'nmod')
# ('(', '19', 'punct')
# ('79/92', '19', 'nummod')
# ('and', '18', 'cc')
# ('85.9', '16', 'conj')
# ('%', '14', 'appos')
# (')', '19', 'punct')
# ('.', '10', 'punct')
# ('The', '5', 'det')
# ('second', '5', 'amod')
# ('common', '5', 'amod')
# ('gene', '5', 'compound')
# ('mutation', '7', 'nsubj')
# ('was', '7', 'cop')
# ('G13513A', '0', 'root')
# ('(', '7', 'punct')
# ('7/92', '7', 'appos')
# ('and', '11', 'cc')
# ('7.6', '9', 'conj')
# ('%', '9', 'conj')
# (')', '12', 'punct')
# ('.', '7', 'punct')
# ('Additionally', '4', 'advmod')
# (',', '4', 'punct')
# ('we', '4', 'nsubj')
# ('identified', '0', 'root')
# ('T10191C', '4', 'obj')
# ('(', '7', 'punct')
# ('p.S45P', '5', 'appos')
# (')', '7', 'punct')
# ('in', '10', 'case')
# ('ND3', '4', 'obl')
# (',', '10', 'punct')
# ('A11470C', '10', 'appos')
# ('(', '15', 'punct')
# ('p.', '15', 'compound')
# ('K237N', '12', 'appos')
# (')', '15', 'punct')
# ('in', '18', 'case')
# ('ND4', '4', 'obl')
# (',', '18', 'punct')
# ('T13046C', '18', 'nummod')
# ('(', '22', 'punct')
# ('p.M237T', '18', 'appos')
# (')', '22', 'punct')
# ('in', '25', 'case')
# ('ND5', '22', 'nmod')
# ('and', '31', 'cc')
# ('a', '31', 'det')
# ('large', '30', 'amod')
# ('-', '30', 'punct')
# ('scale', '31', 'compound')
# ('deletion', '5', 'conj')
# ('(', '33', 'punct')
# ('13025', '31', 'appos')
# ('-', '35', 'case')
# ('13033:14417-14425', '33', 'nmod')
# (')', '33', 'punct')
# ('involving', '31', 'acl')
# ('partial', '39', 'amod')
# ('ND5', '37', 'obj')
# ('and', '42', 'cc')
# ('ND6', '42', 'compound')
# ('subunits', '39', 'conj')
# ('of', '44', 'case')
# ('complex', '42', 'nmod')
# ('I', '48', 'nsubj')
# ('in', '48', 'case')
# ('one', '48', 'nummod')
# ('patient', '44', 'obl')
# ('each', '48', 'nmod:npmod')
# ('.', '4', 'punct')
# ('Among', '2', 'case')
# ('them', '13', 'obl')
# (',', '4', 'punct')
# ('A11470C', '13', 'nsubj')
# (',', '6', 'punct')
# ('T13046C', '4', 'conj')
# ('and', '10', 'cc')
# ('the', '10', 'det')
# ('single', '10', 'amod')
# ('deletion', '4', 'conj')
# ('were', '13', 'cop')
# ('novel', '13', 'compound')
# ('mutations', '0', 'root')
# ('.', '13', 'punct')
# ('In', '2', 'case')
# ('summary', '15', 'obl')
# (',', '15', 'punct')
# ('patients', '15', 'nsubj')
# ('with', '6', 'case')
# ('mutations', '4', 'nmod')
# ('affecting', '4', 'acl')
# ('mitochondrially', '9', 'advmod')
# ('encoded', '10', 'amod')
# ('complex', '7', 'obj')
# ('I', '13', 'nsubj')
# ('(', '13', 'punct')
# ('MTND', '10', 'appos')
# (')', '13', 'punct')
# ('reached', '0', 'root')
# ('12.0', '17', 'nummod')
# ('%', '15', 'obj')
# ('(', '19', 'punct')
# ('11/92', '17', 'appos')
# (')', '17', 'punct')
# ('in', '23', 'case')
# ('this', '23', 'det')
# ('group', '15', 'obl')
# ('.', '15', 'punct')
# ('It', '3', 'expl')
# ('is', '3', 'cop')
# ('noteworthy', '0', 'root')
# ('that', '15', 'mark')
# ('all', '7', 'det')
# ('seven', '7', 'nummod')
# ('patients', '15', 'nsubj:pass')
# ('with', '13', 'case')
# ('MELAS', '13', 'compound')
# ('/', '11', 'cc')
# ('LS', '9', 'conj')
# ('overlap', '13', 'amod')
# ('syndrome', '7', 'nmod')
# ('were', '15', 'aux:pass')
# ('associated', '3', 'csubj')
# ('with', '18', 'case')
# ('MTND', '18', 'compound')
# ('mutations', '15', 'obl')
# ('.', '3', 'punct')
# ('Our', '2', 'nmod:poss')
# ('data', '3', 'nsubj')
# ('emphasize', '0', 'root')
# ('the', '6', 'det')
# ('important', '6', 'amod')
# ('role', '3', 'obj')
# ('of', '9', 'case')
# ('MTND', '9', 'compound')
# ('mutations', '6', 'nmod')
# ('in', '12', 'case')
# ('the', '12', 'det')
# ('pathogenicity', '6', 'nmod')
# ('of', '14', 'case')
# ('MELAS', '12', 'nmod')
# (',', '12', 'punct')
# ('especially', '21', 'advmod')
# ('MELAS', '21', 'compound')
# ('/', '19', 'punct')
# ('LS', '17', 'conj')
# ('overlap', '21', 'amod')
# ('syndrome', '14', 'conj')
# ('.', '3', 'punct')
# ('Novel', '2', 'compound')
# ('compound', '4', 'compound')
# ('heterozygous', '4', 'amod')
# ('mutation', '0', 'root')
# ('of', '6', 'case')
# ('MLYCD', '4', 'nmod')
# ('in', '10', 'case')
# ('a', '10', 'det')
# ('Chinese', '10', 'amod')
# ('patient', '4', 'nmod')
# ('with', '13', 'case')
# ('malonic', '13', 'amod')
# ('aciduria', '10', 'nmod')
# ('.', '4', 'punct')
# ('A', '8', 'det')
# ('3', '4', 'nummod')
# ('-', '4', 'punct')
# ('year', '6', 'obl:npmod')
# ('-', '6', 'punct')
# ('old', '8', 'amod')
# ('Chinese', '8', 'amod')
# ('boy', '0', 'root')
# ('presented', '8', 'acl')
# ('with', '13', 'case')
# ('prominent', '13', 'amod')
# ('clinical', '13', 'amod')
# ('features', '9', 'obl')
# ('of', '16', 'case')
# ('malonic', '16', 'amod')
# ('aciduria', '13', 'nmod')
# (',', '13', 'punct')
# ('including', '20', 'case')
# ('developmental', '20', 'amod')
# ('delay', '8', 'nmod')
# (',', '23', 'punct')
# ('short', '23', 'amod')
# ('stature', '20', 'conj')
# (',', '26', 'punct')
# ('brain', '26', 'compound')
# ('abnormalities', '20', 'conj')
# ('and', '29', 'cc')
# ('massive', '29', 'amod')
# ('excretion', '20', 'conj')
# ('of', '32', 'case')
# ('malonic', '32', 'amod')
# ('acid', '29', 'nmod')
# ('and', '35', 'cc')
# ('methylmalonic', '35', 'amod')
# ('acid', '32', 'conj')
# ('.', '8', 'punct')
# ('Molecular', '2', 'compound')
# ('characterization', '18', 'nsubj')
# ('by', '6', 'case')
# ('DNA', '5', 'compound')
# ('sequencing', '6', 'compound')
# ('analysis', '2', 'nmod')
# ('and', '13', 'cc')
# ('multiplex', '13', 'amod')
# ('ligation', '11', 'obl:npmod')
# ('-', '11', 'punct')
# ('dependent', '13', 'amod')
# ('probe', '13', 'compound')
# ('amplification', '6', 'conj')
# ('of', '17', 'case')
# ('the', '17', 'det')
# ('MLYCD', '17', 'compound')
# ('gene', '13', 'nmod')
# ('revealed', '0', 'root')
# ('a', '21', 'det')
# ('heterozygous', '21', 'compound')
# ('mutation', '18', 'obj')
# ('(', '24', 'punct')
# ('c.920', '24', 'punct')
# ('T', '21', 'appos')
# ('>', '24', 'punct')
# ('G', '21', 'appos')
# (',', '29', 'punct')
# ('p.Leu307', '29', 'compound')
# ('Arg', '26', 'appos')
# (')', '29', 'punct')
# ('in', '33', 'case')
# ('the', '33', 'det')
# ('patient', '21', 'nmod')
# ('and', '36', 'cc')
# ('his', '36', 'nmod:poss')
# ('father', '33', 'conj')
# ('and', '40', 'cc')
# ('a', '40', 'det')
# ('heterozygous', '40', 'amod')
# ('deletion', '33', 'conj')
# ('comprising', '40', 'acl')
# ('exon', '41', 'obj')
# ('1', '42', 'nummod')
# ('in', '46', 'case')
# ('the', '46', 'det')
# ('patient', '41', 'obl')
# ('and', '49', 'cc')
# ('his', '49', 'nmod:poss')
# ('mother', '46', 'conj')
# ('.', '18', 'punct')
# ('The', '3', 'det')
# ('missense', '3', 'compound')
# ('mutation', '10', 'nsubj:pass')
# ('(', '6', 'punct')
# ('c.920T>', '6', 'compound')
# ('G', '3', 'appos')
# (')', '6', 'punct')
# ('was', '10', 'aux:pass')
# ('not', '10', 'advmod')
# ('found', '0', 'root')
# ('in', '14', 'case')
# ('100', '14', 'nummod')
# ('healthy', '14', 'amod')
# ('controls', '10', 'obl')
# ('and', '19', 'cc')
# ('has', '19', 'aux')
# ('not', '19', 'advmod')
# ('been', '19', 'aux:pass')
# ('reported', '10', 'conj')
# ('previously', '19', 'advmod')
# ('.', '10', 'punct')
# ('Our', '2', 'nmod:poss')
# ('findings', '3', 'nsubj')
# ('expand', '0', 'root')
# ('the', '5', 'det')
# ('number', '3', 'obj')
# ('of', '8', 'case')
# ('reported', '8', 'amod')
# ('cases', '5', 'nmod')
# ('and', '10', 'cc')
# ('add', '3', 'conj')
# ('a', '13', 'det')
# ('novel', '13', 'compound')
# ('entry', '10', 'obj')
# ('to', '16', 'case')
# ('the', '16', 'det')
# ('repertoire', '13', 'nmod')
# ('of', '19', 'case')
# ('MLYCD', '19', 'compound')
# ('mutations', '16', 'nmod')
# ('.', '3', 'punct')
# ('Genetic', '4', 'compound')
# ('and', '3', 'cc')
# ('epigenetic', '1', 'conj')
# ('alterations', '0', 'root')
# ('of', '8', 'case')
# ('the', '8', 'det')
# ('NF2', '8', 'compound')
# ('gene', '4', 'nmod')
# ('in', '12', 'case')
# ('sporadic', '12', 'amod')
# ('vestibular', '12', 'amod')
# ('schwannomas', '8', 'nmod')
# ('.', '4', 'punct')
# ('BACKGROUND', '0', 'root')
# (':', '1', 'punct')
# ('Mutations', '16', 'nsubj:pass')
# ('in', '5', 'case')
# ('the', '5', 'det')
# ('neurofibromatosis', '5', 'compound')
# ('type', '1', 'nmod')
# ('2', '5', 'nummod')
# ('(', '8', 'punct')
# ('NF2', '13', 'compound')
# (')', '8', 'punct')
# ('tumor', '12', 'compound')
# ('-', '12', 'punct')
# ('suppressor', '13', 'compound')
# ('gene', '16', 'nsubj:pass')
# ('have', '16', 'aux')
# ('been', '16', 'aux:pass')
# ('identified', '0', 'root')
# ('in', '23', 'case')
# ('not', '19', 'advmod')
# ('only', '22', 'advmod')
# ('NF2', '22', 'amod')
# ('-', '22', 'punct')
# ('related', '23', 'amod')
# ('tumors', '16', 'obl')
# ('but', '28', 'cc')
# ('also', '28', 'advmod')
# ('sporadic', '28', 'amod')
# ('vestibular', '28', 'amod')
# ('schwannomas', '23', 'conj')
# ('(', '28', 'punct')
# ('VS', '28', 'advmod')
# (')', '28', 'punct')
# ('.', '16', 'punct')
# ('This', '2', 'det')
# ('study', '3', 'nsubj')
# ('investigated', '0', 'root')
# ('the', '8', 'det')
# ('genetic', '8', 'amod')
# ('and', '7', 'cc')
# ('epigenetic', '5', 'conj')
# ('alterations', '3', 'obj')
# ('in', '10', 'case')
# ('tumors', '8', 'nmod')
# ('and', '12', 'cc')
# ('blood', '10', 'conj')
# ('from', '16', 'case')
# ('30', '16', 'nummod')
# ('Korean', '16', 'amod')
# ('patients', '3', 'obl')
# ('with', '19', 'case')
# ('sporadic', '19', 'amod')
# ('VS', '16', 'nmod')
# ('and', '21', 'cc')
# ('correlated', '3', 'conj')
# ('these', '23', 'det')
# ('alterations', '21', 'obj')
# ('with', '26', 'case')
# ('tumor', '26', 'compound')
# ('behavior', '21', 'obl')
# ('.', '3', 'punct')
# ('METHODOLOGY', '4', 'compound')
# ('/', '3', 'cc')
# ('PRINCIPAL', '1', 'conj')
# ('FINDINGS', '0', 'root')
# (':', '4', 'punct')
# ('NF2', '8', 'compound')
# ('gene', '8', 'compound')
# ('mutations', '10', 'nsubj:pass')
# ('were', '10', 'aux:pass')
# ('detected', '4', 'parataxis')
# ('using', '10', 'advcl')
# ('PCR', '11', 'obj')
# ('and', '14', 'cc')
# ('direct', '12', 'conj')
# ('DNA', '16', 'compound')
# ('sequencing', '11', 'obj')
# ('and', '25', 'cc')
# ('three', '23', 'nummod')
# ('highly', '20', 'advmod')
# ('polymorphic', '23', 'amod')
# ('microsatellite', '23', 'compound')
# ('DNA', '23', 'compound')
# ('markers', '25', 'nsubj:pass')
# ('were', '25', 'aux:pass')
# ('used', '10', 'conj')
# ('to', '27', 'mark')
# ('assess', '25', 'advcl')
# ('the', '29', 'det')
# ('loss', '27', 'obj')
# ('of', '31', 'case')
# ('heterozygosity', '29', 'nmod')
# ('(', '33', 'punct')
# ('LOH', '31', 'appos')
# (')', '33', 'punct')
# ('from', '36', 'case')
# ('chromosome', '27', 'obl')
# ('22', '0', 'root')
# ('.', '1', 'punct')
# ('Aberrant', '2', 'amod')
# ('hypermethylation', '13', 'nsubj:pass')
# ('of', '6', 'case')
# ('the', '6', 'det')
# ('CpG', '6', 'compound')
# ('island', '2', 'nmod')
# ('of', '10', 'case')
# ('the', '10', 'det')
# ('NF2', '10', 'compound')
# ('gene', '6', 'nmod')
# ('was', '13', 'aux:pass')
# ('also', '13', 'advmod')
# ('analyzed', '0', 'root')
# ('.', '13', 'punct')
# ('The', '3', 'det')
# ('tumor', '3', 'compound')
# ('size', '23', 'nsubj:pass')
# (',', '8', 'punct')
# ('the', '8', 'det')
# ('clinical', '8', 'amod')
# ('growth', '8', 'compound')
# ('index', '3', 'conj')
# (',', '13', 'punct')
# ('and', '13', 'cc')
# ('the', '13', 'det')
# ('proliferative', '13', 'amod')
# ('activity', '3', 'conj')
# ('assessed', '13', 'acl')
# ('using', '14', 'advcl')
# ('the', '21', 'det')
# ('Ki', '21', 'compound')
# ('-', '21', 'punct')
# ('67', '17', 'nummod')
# ('labeling', '21', 'compound')
# ('index', '15', 'obj')
# ('were', '23', 'aux:pass')
# ('evaluated', '0', 'root')
# ('.', '23', 'punct')
# ('We', '2', 'nsubj')
# ('found', '0', 'root')
# ('18', '4', 'nummod')
# ('mutations', '2', 'obj')
# ('in', '7', 'case')
# ('16', '7', 'nummod')
# ('cases', '2', 'obl')
# ('of', '10', 'case')
# ('30', '10', 'nummod')
# ('schwannomas', '7', 'nmod')
# ('(', '13', 'punct')
# ('53', '13', 'nummod')
# ('%', '10', 'appos')
# (')', '13', 'punct')
# ('.', '2', 'punct')
# ('The', '2', 'det')
# ('mutations', '3', 'nsubj')
# ('included', '0', 'root')
# ('eight', '6', 'nummod')
# ('frameshift', '6', 'compound')
# ('mutations', '3', 'obj')
# (',', '10', 'punct')
# ('seven', '10', 'nummod')
# ('nonsense', '10', 'compound')
# ('mutations', '6', 'conj')
# (',', '16', 'punct')
# ('one', '16', 'nummod')
# ('in', '15', 'case')
# ('-', '15', 'punct')
# ('frame', '16', 'compound')
# ('deletion', '6', 'conj')
# (',', '21', 'punct')
# ('one', '21', 'nummod')
# ('splicing', '20', 'compound')
# ('donor', '21', 'compound')
# ('site', '6', 'conj')
# (',', '26', 'punct')
# ('and', '26', 'cc')
# ('one', '26', 'nummod')
# ('missense', '26', 'compound')
# ('mutation', '6', 'conj')
# ('.', '3', 'punct')
# ('Nine', '2', 'nummod')
# ('patients', '7', 'nsubj')
# ('(', '5', 'punct')
# ('30', '5', 'nummod')
# ('%', '2', 'appos')
# (')', '5', 'punct')
# ('showed', '0', 'root')
# ('allelic', '9', 'amod')
# ('loss', '7', 'obj')
# ('.', '7', 'punct')
# ('No', '2', 'det')
# ('patient', '3', 'nsubj')
# ('had', '0', 'root')
# ('aberrant', '5', 'amod')
# ('hypermethylation', '3', 'obj')
# ('of', '9', 'case')
# ('the', '9', 'det')
# ('NF2', '9', 'compound')
# ('gene', '5', 'nmod')
# ('and', '11', 'cc')
# ('correlation', '5', 'conj')
# ('between', '15', 'case')
# ('NF2', '15', 'compound')
# ('genetic', '15', 'amod')
# ('alterations', '11', 'nmod')
# ('and', '18', 'cc')
# ('tumor', '18', 'compound')
# ('behavior', '15', 'conj')
# ('was', '21', 'aux:pass')
# ('not', '21', 'advmod')
# ('observed', '3', 'conj')
# ('in', '24', 'case')
# ('this', '24', 'det')
# ('study', '21', 'obl')
# ('.', '3', 'punct')
# ('CONCLUSIONS', '0', 'root')
# ('/', '3', 'cc')
# ('SIGNIFICANCE', '1', 'conj')
# (':', '1', 'punct')
# ('The', '4', 'det')
# ('molecular', '4', 'amod')
# ('genetic', '4', 'amod')
# ('changes', '8', 'nsubj')
# ('in', '7', 'case')
# ('sporadic', '7', 'amod')
# ('VS', '4', 'nmod')
# ('identified', '0', 'root')
# ('here', '10', 'advmod')
# ('included', '8', 'ccomp')
# ('mutations', '10', 'obj')
# ('and', '14', 'cc')
# ('allelic', '14', 'amod')
# ('loss', '11', 'conj')
# (',', '25', 'punct')
# ('but', '25', 'cc')
# ('no', '19', 'det')
# ('aberrant', '19', 'amod')
# ('hypermethylation', '25', 'nsubj:pass')
# ('of', '23', 'case')
# ('the', '23', 'det')
# ('NF2', '23', 'compound')
# ('gene', '19', 'nmod')
# ('was', '25', 'aux:pass')
# ('detected', '8', 'conj')
# ('.', '8', 'punct')
# ('In', '2', 'case')
# ('addition', '11', 'obl')
# (',', '11', 'punct')
# ('no', '9', 'det')
# ('clear', '9', 'amod')
# ('genotype', '9', 'compound')
# ('/', '8', 'cc')
# ('phenotype', '9', 'compound')
# ('correlation', '11', 'nsubj:pass')
# ('was', '11', 'aux:pass')
# ('identified', '0', 'root')
# ('.', '11', 'punct')
# ('Therefore', '5', 'advmod')
# (',', '5', 'punct')
# ('it', '5', 'expl')
# ('is', '5', 'cop')
# ('likely', '0', 'root')
# ('that', '9', 'mark')
# ('other', '8', 'amod')
# ('factors', '9', 'nsubj')
# ('contribute', '5', 'ccomp')
# ('to', '12', 'case')
# ('tumor', '12', 'compound')
# ('formation', '9', 'obl')
# ('and', '14', 'cc')
# ('growth', '12', 'conj')
# ('.', '5', 'punct')
# ('RET', '3', 'compound')
# ('mutational', '3', 'amod')
# ('spectrum', '0', 'root')
# ('in', '6', 'case')
# ('Hirschsprung', '6', 'compound')
# ('disease', '3', 'nmod')
# (':', '3', 'punct')
# ('evaluation', '3', 'appos')
# ('of', '12', 'case')
# ('601', '12', 'nummod')
# ('Chinese', '12', 'amod')
# ('patients', '8', 'nmod')
# ('.', '3', 'punct')
# ('Rare', '3', 'amod')
# ('(', '3', 'punct')
# ('RVs', '12', 'nsubj')
# (')', '3', 'punct')
# ('and', '7', 'cc')
# ('common', '7', 'amod')
# ('variants', '12', 'nsubj')
# ('of', '11', 'case')
# ('the', '11', 'det')
# ('RET', '11', 'compound')
# ('gene', '7', 'nmod')
# ('contribute', '0', 'root')
# ('to', '15', 'case')
# ('Hirschsprung', '15', 'compound')
# ('disease', '12', 'obl')
# ('(', '17', 'punct')
# ('HSCR', '15', 'appos')
# (';', '15', 'punct')
# ('congenital', '20', 'amod')
# ('aganglionosis', '15', 'appos')
# (')', '20', 'punct')
# ('.', '12', 'punct')
# ('While', '7', 'mark')
# ('RET', '4', 'compound')
# ('common', '4', 'amod')
# ('variants', '7', 'nsubj:pass')
# ('are', '7', 'aux:pass')
# ('strongly', '7', 'advmod')
# ('associated', '36', 'advcl')
# ('with', '11', 'case')
# ('the', '11', 'det')
# ('commonest', '11', 'amod')
# ('manifestation', '7', 'obl')
# ('of', '14', 'case')
# ('the', '14', 'det')
# ('disease', '11', 'nmod')
# ('(', '16', 'punct')
# ('males', '14', 'appos')
# (';', '16', 'punct')
# ('short', '20', 'amod')
# ('-', '20', 'punct')
# ('segment', '21', 'compound')
# ('aganglionosis', '16', 'appos')
# (';', '16', 'punct')
# ('sporadic', '21', 'amod')
# (')', '16', 'punct')
# (',', '28', 'punct')
# ('rare', '28', 'amod')
# ('coding', '28', 'compound')
# ('sequence', '32', 'compound')
# ('(', '30', 'punct')
# ('CDS', '28', 'appos')
# (')', '30', 'punct')
# ('variants', '36', 'nsubj:pass')
# ('are', '36', 'aux:pass')
# ('more', '35', 'advmod')
# ('frequently', '36', 'advmod')
# ('found', '0', 'root')
# ('in', '44', 'case')
# ('the', '44', 'det')
# ('lesser', '44', 'amod')
# ('common', '44', 'amod')
# ('and', '43', 'cc')
# ('more', '43', 'advmod')
# ('severe', '40', 'conj')
# ('forms', '36', 'obl')
# ('of', '47', 'case')
# ('the', '47', 'det')
# ('disease', '44', 'nmod')
# ('(', '49', 'punct')
# ('females', '47', 'appos')
# (';', '49', 'punct')
# ('long', '55', 'amod')
# ('/', '53', 'punct')
# ('total', '51', 'conj')
# ('colonic', '55', 'compound')
# ('aganglionosis', '49', 'parataxis')
# (';', '55', 'punct')
# ('familial', '55', 'appos')
# (')', '49', 'punct')
# ('.', '49', 'punct')
# ('Here', '3', 'advmod')
# ('we', '3', 'nsubj')
# ('present', '29', 'ccomp')
# ('the', '5', 'det')
# ('screening', '3', 'obj')
# ('for', '7', 'case')
# ('RVs', '5', 'nmod')
# ('in', '11', 'case')
# ('the', '11', 'det')
# ('RET', '11', 'compound')
# ('CDS', '5', 'nmod')
# ('and', '16', 'cc')
# ('intron', '16', 'compound')
# ('/', '15', 'cc')
# ('exon', '13', 'conj')
# ('boundaries', '11', 'conj')
# ('of', '21', 'case')
# ('601', '21', 'nummod')
# ('Chinese', '21', 'amod')
# ('HSCR', '21', 'compound')
# ('patients', '16', 'nmod')
# (',', '29', 'punct')
# ('the', '25', 'det')
# ('largest', '25', 'amod')
# ('number', '29', 'nsubj')
# ('of', '27', 'case')
# ('patients', '25', 'nmod')
# ('ever', '29', 'advmod')
# ('reported', '0', 'root')
# ('.', '29', 'punct')
# ('We', '2', 'nsubj')
# ('identified', '0', 'root')
# ('61', '6', 'nummod')
# ('different', '6', 'amod')
# ('heterozygous', '6', 'compound')
# ('RVs', '2', 'obj')
# ('(', '9', 'punct')
# ('50', '9', 'nummod')
# ('novel', '6', 'appos')
# (')', '9', 'punct')
# ('distributed', '6', 'acl')
# ('among', '14', 'case')
# ('100', '14', 'nummod')
# ('patients', '11', 'obl')
# ('(', '17', 'punct')
# ('16.64', '17', 'nummod')
# ('%', '14', 'appos')
# (')', '17', 'punct')
# ('.', '2', 'punct')
# ('Those', '2', 'nsubj')
# ('include', '0', 'root')
# ('14', '7', 'nummod')
# ('silent', '7', 'amod')
# (',', '7', 'punct')
# ('29', '7', 'nummod')
# ('missense', '2', 'obj')
# (',', '10', 'punct')
# ('5', '10', 'nummod')
# ('nonsense', '7', 'conj')
# (',', '13', 'punct')
# ('4', '13', 'nummod')
# ('frame-shifts', '7', 'conj')
# (',', '23', 'punct')
# ('and', '23', 'cc')
# ('one', '23', 'nummod')
# ('in', '19', 'case')
# ('-', '19', 'punct')
# ('frame', '23', 'compound')
# ('amino', '22', 'compound')
# ('-', '22', 'punct')
# ('acid', '23', 'compound')
# ('deletion', '7', 'conj')
# ('in', '26', 'case')
# ('the', '26', 'det')
# ('CDS', '23', 'nmod')
# (',', '23', 'punct')
# ('two', '32', 'nummod')
# ('splice', '31', 'amod')
# ('-', '31', 'punct')
# ('site', '32', 'compound')
# ('deletions', '26', 'conj')
# (',', '36', 'punct')
# ('4', '36', 'nummod')
# ('nucleotide', '36', 'compound')
# ('substitutions', '32', 'conj')
# ('and', '42', 'cc')
# ('a', '42', 'det')
# ('22', '41', 'nummod')
# ('-', '41', 'punct')
# ('bp', '42', 'compound')
# ('deletion', '7', 'conj')
# ('in', '48', 'case')
# ('the', '48', 'det')
# ('intron', '48', 'compound')
# ('/', '47', 'cc')
# ('exon', '45', 'conj')
# ('boundaries', '42', 'nmod')
# ('and', '54', 'cc')
# ('1', '54', 'nummod')
# ('single', '53', 'amod')
# ('-', '53', 'punct')
# ('nucleotide', '54', 'compound')
# ('substitution', '48', 'conj')
# ('in', '60', 'case')
# ('the', '60', 'det')
# ('5', '60', 'nummod')
# ("'", '60', 'punct')
# ('untranslated', '60', 'amod')
# ('region', '54', 'nmod')
# ('.', '2', 'punct')
# ('Exonic', '2', 'compound')
# ('variants', '5', 'nsubj:pass')
# ('were', '5', 'aux:pass')
# ('mainly', '5', 'advmod')
# ('clustered', '0', 'root')
# ('in', '7', 'case')
# ('RET', '5', 'obl')
# ('the', '10', 'det')
# ('extracellular', '10', 'amod')
# ('domain', '5', 'obl')
# ('.', '5', 'punct')
# ('RET', '2', 'compound')
# ('RV', '6', 'nsubj')
# ('s', '2', 'case')
# ('were', '6', 'cop')
# ('more', '6', 'advmod')
# ('frequent', '0', 'root')
# ('among', '8', 'case')
# ('patients', '6', 'obl')
# ('with', '13', 'case')
# ('the', '13', 'det')
# ('most', '12', 'advmod')
# ('severe', '13', 'amod')
# ('phenotype', '8', 'nmod')
# ('(', '16', 'punct')
# ('24', '16', 'nummod')
# ('%', '13', 'appos')
# ('vs.', '19', 'case')
# ('15', '19', 'nummod')
# ('%', '16', 'nmod')
# ('in', '23', 'case')
# ('short', '23', 'amod')
# ('-', '23', 'punct')
# ('HSCR', '19', 'nmod')
# (')', '16', 'punct')
# ('.', '6', 'punct')
# ('Phasing', '10', 'csubj')
# ('RVs', '1', 'obj')
# ('with', '9', 'case')
# ('the', '9', 'det')
# ('RET', '9', 'compound')
# ('HSCR', '8', 'obl:npmod')
# ('-', '8', 'punct')
# ('associated', '9', 'amod')
# ('haplotype', '1', 'obl')
# ('suggests', '0', 'root')
# ('that', '16', 'mark')
# ('RV', '16', 'nsubj')
# ('s', '12', 'case')
# ('do', '16', 'aux')
# ('not', '16', 'advmod')
# ('underlie', '10', 'ccomp')
# ('the', '19', 'det')
# ('undisputable', '19', 'amod')
# ('association', '16', 'obj')
# ('of', '23', 'case')
# ('RET', '23', 'compound')
# ('common', '23', 'amod')
# ('variants', '19', 'nmod')
# ('with', '25', 'case')
# ('HSCR', '23', 'nmod')
# ('.', '10', 'punct')
# ('None', '6', 'nsubj:pass')
# ('of', '4', 'case')
# ('the', '4', 'det')
# ('variants', '1', 'nmod')
# ('were', '6', 'aux:pass')
# ('found', '0', 'root')
# ('in', '10', 'case')
# ('250', '10', 'nummod')
# ('Chinese', '10', 'amod')
# ('controls', '6', 'obl')
# ('.', '6', 'punct')
# ('A', '2', 'det')
# ('deletion', '0', 'root')
# ('of', '4', 'case')
# ('FGFR2', '2', 'nmod')
# ('creating', '4', 'acl')
# ('a', '11', 'det')
# ('chimeric', '11', 'amod')
# ('IIIb', '11', 'compound')
# ('/', '10', 'punct')
# ('IIIc', '8', 'conj')
# ('exon', '5', 'obj')
# ('in', '14', 'case')
# ('a', '14', 'det')
# ('child', '5', 'obl')
# ('with', '17', 'case')
# ('Apert', '17', 'compound')
# ('syndrome', '14', 'nmod')
# ('.', '2', 'punct')
# ('BACKGROUND', '0', 'root')
# (':', '1', 'punct')
# ('Signalling', '13', 'advcl')
# ('by', '7', 'case')
# ('fibroblast', '4', 'compound')
# ('growth', '7', 'compound')
# ('factor', '7', 'compound')
# ('receptor', '7', 'compound')
# ('type', '1', 'obl')
# ('2', '7', 'nummod')
# ('(', '10', 'punct')
# ('FGFR2', '7', 'appos')
# (')', '10', 'punct')
# ('normally', '13', 'advmod')
# ('involves', '0', 'root')
# ('a', '20', 'det')
# ('tissue', '17', 'obl:npmod')
# ('-', '17', 'punct')
# ('specific', '20', 'amod')
# ('alternative', '20', 'amod')
# ('splice', '20', 'amod')
# ('choice', '13', 'obj')
# ('between', '23', 'case')
# ('two', '23', 'nummod')
# ('exons', '20', 'nmod')
# ('(', '25', 'punct')
# ('IIIb', '23', 'appos')
# ('and', '27', 'cc')
# ('IIIc', '25', 'conj')
# (')', '25', 'punct')
# (',', '23', 'punct')
# ('which', '31', 'nsubj')
# ('generates', '23', 'acl:relcl')
# ('two', '34', 'nummod')
# ('receptor', '34', 'compound')
# ('isoforms', '31', 'obj')
# ('(', '36', 'punct')
# ('FGFR2b', '34', 'appos')
# ('and', '38', 'cc')
# ('FGFR2c', '36', 'conj')
# ('respectively', '36', 'advmod')
# (')', '36', 'punct')
# ('with', '43', 'case')
# ('differing', '43', 'amod')
# ('repertoires', '31', 'obl')
# ('of', '48', 'case')
# ('FGF', '47', 'compound')
# ('-', '47', 'punct')
# ('binding', '48', 'compound')
# ('specificity', '43', 'nmod')
# ('.', '13', 'punct')
# ('Here', '3', 'advmod')
# ('we', '3', 'nsubj')
# ('describe', '0', 'root')
# ('a', '10', 'det')
# ('unique', '10', 'amod')
# ('chimeric', '10', 'amod')
# ('IIIb', '10', 'compound')
# ('/', '9', 'case')
# ('c', '10', 'compound')
# ('exon', '3', 'obj')
# ('in', '13', 'case')
# ('a', '13', 'det')
# ('patient', '10', 'nmod')
# ('with', '16', 'case')
# ('Apert', '16', 'compound')
# ('syndrome', '13', 'nmod')
# (',', '16', 'punct')
# ('generated', '10', 'acl')
# ('by', '24', 'case')
# ('a', '24', 'det')
# ('non-allelic', '24', 'amod')
# ('homologous', '24', 'amod')
# ('recombination', '24', 'compound')
# ('event', '18', 'obl')
# ('.', '3', 'punct')
# ('CASE', '2', 'compound')
# ('PRESENTATION', '0', 'root')
# (':', '2', 'punct')
# ('We', '2', 'nsubj')
# ('present', '0', 'root')
# ('a', '4', 'det')
# ('child', '2', 'obj')
# ('with', '7', 'case')
# ('Apert', '7', 'compound')
# ('syndrome', '4', 'nmod')
# ('in', '9', 'case')
# ('whom', '14', 'obl')
# ('routine', '12', 'compound')
# ('genetic', '12', 'amod')
# ('testing', '14', 'nsubj')
# ('had', '14', 'aux')
# ('excluded', '4', 'acl:relcl')
# ('the', '18', 'det')
# ('FGFR2', '17', 'compound')
# ('missense', '18', 'compound')
# ('mutations', '14', 'obj')
# ('commonly', '20', 'advmod')
# ('associated', '18', 'acl')
# ('with', '23', 'case')
# ('this', '23', 'det')
# ('disorder', '20', 'obl')
# ('.', '2', 'punct')
# ('The', '2', 'det')
# ('patient', '4', 'nsubj:pass')
# ('was', '4', 'aux:pass')
# ('found', '0', 'root')
# ('to', '6', 'mark')
# ('harbour', '4', 'xcomp')
# ('a', '11', 'det')
# ('heterozygous', '11', 'amod')
# ('1372', '10', 'nummod')
# ('bp', '11', 'compound')
# ('deletion', '6', 'obj')
# ('between', '15', 'case')
# ('FGFR2', '15', 'compound')
# ('exons', '15', 'compound')
# ('IIIb', '11', 'nmod')
# ('and', '17', 'cc')
# ('IIIc', '15', 'conj')
# (',', '6', 'punct')
# ('apparently', '20', 'advmod')
# ('originating', '6', 'advcl')
# ('from', '22', 'case')
# ('recombination', '20', 'obl')
# ('between', '25', 'case')
# ('13', '25', 'nummod')
# ('bp', '22', 'nmod')
# ('of', '30', 'case')
# ('identical', '30', 'amod')
# ('DNA', '29', 'compound')
# ('sequence', '30', 'compound')
# ('present', '25', 'nmod')
# ('in', '33', 'case')
# ('both', '33', 'det')
# ('exons', '30', 'nmod')
# ('.', '4', 'punct')
# ('The', '2', 'det')
# ('rearrangement', '5', 'nsubj')
# ('was', '5', 'cop')
# ('not', '5', 'advmod')
# ('present', '0', 'root')
# ('in', '9', 'case')
# ('the', '9', 'det')
# ('unaffected', '9', 'amod')
# ('parents', '5', 'obl')
# ('.', '5', 'punct')
# ('CONCLUSIONS', '0', 'root')
# (':', '1', 'punct')
# ('Based', '7', 'case')
# ('on', '7', 'case')
# ('the', '7', 'det')
# ('known', '7', 'amod')
# ('pathogenesis', '17', 'obl')
# ('of', '10', 'case')
# ('Apert', '10', 'compound')
# ('syndrome', '7', 'nmod')
# (',', '17', 'punct')
# ('the', '15', 'det')
# ('chimeric', '15', 'amod')
# ('FGFR2', '15', 'compound')
# ('protein', '17', 'nsubj:pass')
# ('is', '17', 'aux:pass')
# ('predicted', '1', 'appos')
# ('to', '19', 'mark')
# ('act', '17', 'xcomp')
# ('in', '28', 'case')
# ('a', '28', 'det')
# ('dominant', '28', 'amod')
# ('gain', '28', 'compound')
# ('-', '23', 'punct')
# ('of', '27', 'case')
# ('-', '27', 'punct')
# ('function', '23', 'nmod')
# ('manner', '19', 'obl')
# ('.', '1', 'punct')
# ('This', '3', 'nsubj')
# ('is', '3', 'cop')
# ('likely', '0', 'root')
# ('to', '5', 'mark')
# ('result', '3', 'xcomp')
# ('from', '8', 'case')
# ('its', '8', 'nmod:poss')
# ('expression', '5', 'obl')
# ('in', '11', 'case')
# ('mesenchymal', '11', 'amod')
# ('tissues', '8', 'nmod')
# (',', '11', 'punct')
# ('where', '27', 'advmod')
# ('retention', '27', 'nsubj')
# ('of', '16', 'case')
# ('most', '14', 'nmod')
# ('of', '19', 'case')
# ('the', '19', 'det')
# ('residues', '16', 'nmod')
# ('essential', '19', 'amod')
# ('for', '25', 'case')
# ('FGFR2', '23', 'compound')
# ('b', '25', 'compound')
# ('binding', '25', 'compound')
# ('activity', '20', 'obl')
# ('would', '27', 'aux')
# ('result', '5', 'ccomp')
# ('in', '30', 'case')
# ('autocrine', '30', 'amod')
# ('activation', '27', 'obl')
# ('.', '3', 'punct')
# ('This', '2', 'det')
# ('report', '3', 'nsubj')
# ('adds', '0', 'root')
# ('to', '6', 'case')
# ('the', '6', 'det')
# ('repertoire', '3', 'obl')
# ('of', '9', 'case')
# ('rare', '9', 'amod')
# ('cases', '6', 'nmod')
# ('of', '12', 'case')
# ('Apert', '12', 'compound')
# ('syndrome', '9', 'nmod')
# ('for', '14', 'case')
# ('which', '24', 'obl')
# ('a', '16', 'det')
# ('pathogenesis', '24', 'nsubj:pass')
# ('based', '16', 'acl')
# ('on', '21', 'case')
# ('atypical', '21', 'amod')
# ('FGFR2', '21', 'compound')
# ('rearrangements', '17', 'obl')
# ('can', '24', 'aux')
# ('be', '24', 'aux:pass')
# ('demonstrated', '6', 'acl:relcl')
# ('.', '3', 'punct')
# ('Detection', '0', 'root')
# ('of', '11', 'case')
# ('a-thalassemia', '5', 'compound')
# ('-', '5', 'punct')
# ('1', '7', 'compound')
# ('Southeast', '11', 'amod')
# ('Asian', '11', 'amod')
# ('and', '10', 'cc')
# ('Thai', '7', 'conj')
# ('type', '7', 'conj')
# ('deletions', '1', 'nmod')
# ('and', '17', 'cc')
# ('b-thalassemia', '17', 'compound')
# ('3.5', '16', 'nummod')
# ('-', '16', 'punct')
# ('kb', '17', 'compound')
# ('deletion', '11', 'conj')
# ('by', '26', 'case')
# ('single', '21', 'amod')
# ('-', '21', 'punct')
# ('tube', '26', 'compound')
# ('multiplex', '26', 'amod')
# ('real', '25', 'amod')
# ('-', '25', 'punct')
# ('time', '26', 'compound')
# ('PCR', '17', 'nmod')
# ('with', '29', 'case')
# ('SYBR', '29', 'compound')
# ('Green1', '26', 'nmod')
# ('and', '35', 'cc')
# ('high', '33', 'amod')
# ('-', '33', 'punct')
# ('resolution', '35', 'compound')
# ('melting', '35', 'compound')
# ('analysis', '29', 'conj')
# ('.', '1', 'punct')
# ('BACKGROUND', '0', 'root')
# (':', '1', 'punct')
# ('Prevention', '8', 'nsubj')
# ('and', '5', 'cc')
# ('control', '3', 'conj')
# ('of', '7', 'case')
# ('thalassemia', '3', 'nmod')
# ('requires', '1', 'parataxis')
# ('simple', '16', 'amod')
# (',', '11', 'punct')
# ('rapid', '9', 'conj')
# (',', '14', 'punct')
# ('and', '14', 'cc')
# ('accurate', '9', 'conj')
# ('screening', '16', 'compound')
# ('tests', '8', 'obj')
# ('for', '19', 'case')
# ('carrier', '19', 'compound')
# ('couples', '16', 'nmod')
# ('who', '23', 'nsubj')
# ('are', '23', 'cop')
# ('at', '23', 'case')
# ('risk', '19', 'acl:relcl')
# ('of', '25', 'mark')
# ('conceiving', '23', 'acl')
# ('fetuses', '25', 'obj')
# ('with', '29', 'case')
# ('severe', '29', 'amod')
# ('thalassemia', '25', 'obl')
# ('.', '1', 'punct')
# ('METHODS', '0', 'root')
# (':', '1', 'punct')
# ('Single', '5', 'amod')
# ('-', '5', 'punct')
# ('tube', '10', 'compound')
# ('multiplex', '10', 'amod')
# ('real', '9', 'amod')
# ('-', '9', 'punct')
# ('time', '10', 'compound')
# ('PCR', '1', 'appos')
# ('with', '13', 'case')
# ('SYBR', '13', 'compound')
# ('Green1', '10', 'nmod')
# ('and', '18', 'cc')
# ('high', '17', 'amod')
# ('-', '17', 'punct')
# ('resolution', '18', 'compound')
# ('melting', '10', 'conj')
# ('(', '20', 'punct')
# ('HRM', '18', 'appos')
# (')', '20', 'punct')
# ('analysis', '24', 'nsubj:pass')
# ('were', '24', 'aux:pass')
# ('used', '1', 'appos')
# ('for', '27', 'case')
# ('the', '27', 'det')
# ('identification', '24', 'obl')
# ('of', '35', 'case')
# ('a-thalassemia', '35', 'compound')
# ('-', '35', 'punct')
# ('1', '29', 'nummod')
# ('Southeast', '35', 'compound')
# ('Asian', '35', 'amod')
# ('(', '35', 'punct')
# ('SEA', '40', 'compound')
# (')', '35', 'punct')
# ('and', '40', 'cc')
# ('Thai', '39', 'amod')
# ('type', '40', 'compound')
# ('deletions', '27', 'conj')
# ('and', '47', 'cc')
# ('b-thalassemia', '47', 'compound')
# ('3.5', '45', 'nummod')
# ('-', '45', 'punct')
# ('kb', '47', 'compound')
# ('gene', '47', 'compound')
# ('deletion', '40', 'conj')
# ('.', '1', 'punct')
# ('The', '2', 'det')
# ('results', '4', 'nsubj:pass')
# ('were', '4', 'aux:pass')
# ('compared', '0', 'root')
# ('with', '6', 'case')
# ('those', '4', 'obl')
# ('obtained', '6', 'acl')
# ('using', '7', 'xcomp')
# ('conventional', '12', 'amod')
# ('gap', '12', 'compound')
# ('-', '12', 'punct')
# ('PCR', '8', 'obj')
# ('.', '4', 'punct')
# ('DNA', '2', 'compound')
# ('samples', '4', 'nsubj:pass')
# ('were', '4', 'aux:pass')
# ('derived', '0', 'root')
# ('from', '8', 'case')
# ('28', '8', 'nummod')
# ('normal', '8', 'amod')
# ('individuals', '4', 'obl')
# (',', '8', 'punct')
# ('11', '11', 'nummod')
# ('individuals', '8', 'appos')
# ('with', '18', 'case')
# ('a-thalassemia', '18', 'compound')
# ('-', '17', 'punct')
# ('1', '17', 'nummod')
# ('SEA', '17', 'compound')
# ('type', '18', 'compound')
# ('deletion', '11', 'nmod')
# (',', '18', 'punct')
# ('2', '18', 'appos')
# ('with', '22', 'case')
# ('a-thalassemia', '18', 'nmod')
# ('-', '24', 'punct')
# ('1', '22', 'appos')
# ('Thai', '2', 'amod')
# ('type', '3', 'compound')
# ('deletion', '0', 'root')
# (',', '6', 'punct')
# ('and', '6', 'cc')
# ('2', '3', 'conj')
# ('with', '14', 'case')
# ('heterozygous', '9', 'compound')
# ('b-thalassemia', '14', 'compound')
# ('3.5', '12', 'nummod')
# ('-', '12', 'punct')
# ('kb', '14', 'compound')
# ('gene', '14', 'compound')
# ('deletion', '6', 'nmod')
# ('.', '3', 'punct')
# ('RESULTS', '0', 'root')
# (':', '1', 'punct')
# ('HRM', '4', 'compound')
# ('analysis', '5', 'nsubj')
# ('indicated', '1', 'parataxis')
# ('that', '9', 'mark')
# ('the', '9', 'det')
# ('amplified', '9', 'amod')
# ('fragments', '5', 'ccomp')
# ('from', '16', 'case')
# ('a-thalassemia', '15', 'compound')
# ('-', '15', 'punct')
# ('1', '15', 'nummod')
# ('SEA', '15', 'compound')
# ('type', '16', 'compound')
# ('deletion', '9', 'nmod')
# (',', '16', 'punct')
# ('a-thalassemia', '16', 'appos')
# ('-', '20', 'punct')
# ('1', '18', 'appos')
# ('Thai', '2', 'amod')
# ('type', '3', 'compound')
# ('deletion', '0', 'root')
# (',', '6', 'punct')
# ('b-', '6', 'compound')
# ('thalassemia', '3', 'conj')
# ('3.5', '6', 'nummod')
# ('-', '3', 'punct')
# ('kb', '11', 'compound')
# ('gene', '11', 'compound')
# ('deletion', '3', 'list')
# (',', '20', 'punct')
# ('and', '20', 'cc')
# ('the', '19', 'det')
# ('wild', '17', 'amod')
# ('-', '17', 'punct')
# ('type', '19', 'compound')
# ('b-globin', '19', 'compound')
# ('gene', '20', 'nsubj')
# ('had', '3', 'conj')
# ('specific', '23', 'amod')
# ('peak', '23', 'compound')
# ('heights', '20', 'obj')
# ('at', '27', 'case')
# ('mean', '27', 'compound')
# ('melting', '27', 'compound')
# ('temperature', '23', 'nmod')
# ('(', '31', 'punct')
# ('T', '27', 'appos')
# ('(', '31', 'punct')
# ('m', '29', 'appos')
# (')', '31', 'punct')
# (')', '31', 'punct')
# ('values', '27', 'appos')
# ('of', '36', 'case')
# ('86.89', '34', 'nmod')
# (',', '38', 'punct')
# ('85.66', '36', 'conj')
# (',', '40', 'punct')
# ('77.24', '36', 'conj')
# (',', '43', 'punct')
# ('and', '43', 'cc')
# ('74.92', '36', 'conj')
# (',', '45', 'punct')
# ('respectively', '43', 'advmod')
# ('.', '3', 'punct')
# ('The', '2', 'det')
# ('results', '19', 'nsubj')
# ('obtained', '2', 'acl')
# ('using', '3', 'advcl')
# ('single', '7', 'amod')
# ('-', '7', 'punct')
# ('tube', '12', 'compound')
# ('multiplex', '12', 'amod')
# ('real', '11', 'amod')
# ('-', '11', 'punct')
# ('time', '12', 'compound')
# ('PCR', '4', 'obj')
# ('with', '15', 'case')
# ('SYBR', '15', 'compound')
# ('Green1', '12', 'nmod')
# ('and', '18', 'cc')
# ('HRM', '18', 'compound')
# ('analysis', '15', 'conj')
# ('showed', '0', 'root')
# ('100', '21', 'nummod')
# ('%', '22', 'compound')
# ('consistency', '19', 'obj')
# ('with', '24', 'case')
# ('those', '22', 'nmod')
# ('obtained', '24', 'acl')
# ('using', '25', 'advcl')
# ('conventional', '30', 'amod')
# ('gap', '30', 'compound')
# ('-', '30', 'punct')
# ('PCR', '26', 'obj')
# ('.', '19', 'punct')
# ('CONCLUSIONS', '0', 'root')
# (':', '1', 'punct')
# ('Single', '5', 'amod')
# ('-', '5', 'punct')
# ('tube', '10', 'compound')
# ('multiplex', '10', 'amod')
# ('real', '9', 'amod')
# ('-', '9', 'punct')
# ('time', '10', 'compound')
# ('PCR', '1', 'appos')
# ('with', '13', 'case')
# ('SYBR', '13', 'compound')
# ('Green1', '10', 'nmod')
# ('and', '16', 'cc')
# ('HRM', '16', 'compound')
# ('analysis', '20', 'nsubj')
# ('is', '20', 'cop')
# ('a', '20', 'det')
# ('potential', '20', 'amod')
# ('alternative', '1', 'appos')
# ('for', '24', 'case')
# ('routine', '24', 'compound')
# ('clinical', '24', 'amod')
# ('screening', '20', 'nmod')
# ('of', '28', 'case')
# ('the', '28', 'det')
# ('common', '28', 'amod')
# ('types', '24', 'nmod')
# ('of', '30', 'case')
# ('a-', '28', 'nmod')
# ('and', '35', 'cc')
# ('b-thalassemia', '30', 'conj')
# ('large', '35', 'amod')
# ('gene', '35', 'compound')
# ('deletions', '28', 'nmod')
# (',', '28', 'punct')
# ('since', '40', 'mark')
# ('it', '40', 'nsubj')
# ('is', '40', 'cop')
# ('simple', '20', 'advcl')
# (',', '42', 'punct')
# ('cost-effective', '40', 'conj')
# (',', '46', 'punct')
# ('and', '46', 'cc')
# ('highly', '46', 'advmod')
# ('accurate', '40', 'conj')
# ('.', '1', 'punct')
# ('Xeroderma', '2', 'compound')
# ('pigmentosum', '3', 'compound')
# ('variant', '0', 'root')
# (':', '3', 'punct')
# ('complementary', '7', 'amod')
# ('molecular', '7', 'amod')
# ('approaches', '3', 'appos')
# ('to', '9', 'mark')
# ('detect', '7', 'acl')
# ('a', '14', 'det')
# ('13', '13', 'nummod')
# ('base', '13', 'compound')
# ('pair', '14', 'compound')
# ('deletion', '9', 'obj')
# ('in', '20', 'case')
# ('the', '20', 'det')
# ('DNA', '18', 'compound')
# ('polymerase', '20', 'compound')
# ('eta', '20', 'compound')
# ('gene', '14', 'nmod')
# ('.', '3', 'punct')
# ('Deficiencies', '0', 'root')
# ('of', '7', 'case')
# ('DNA', '4', 'compound')
# ('polymerase', '7', 'compound')
# ('eta', '7', 'compound')
# ('-an', '7', 'compound')
# ('enzyme', '1', 'nmod')
# ('mediating', '7', 'acl')
# ('replication', '8', 'obj')
# ('past', '15', 'case')
# ('UV', '13', 'obl:npmod')
# ('-', '13', 'punct')
# ('induced', '15', 'amod')
# ('DNA', '15', 'compound')
# ('damage', '9', 'nmod')
# ('-', '1', 'punct')
# ('predispose', '1', 'parataxis')
# ('individuals', '17', 'obj')
# ('to', '22', 'case')
# ('xeroderma', '22', 'compound')
# ('pigmentosum', '22', 'compound')
# ('variant', '17', 'obl')
# ('(', '24', 'punct')
# ('XPV', '22', 'appos')
# (')', '24', 'punct')
# ('and', '27', 'cc')
# ('result', '22', 'conj')
# ('in', '31', 'case')
# ('a', '31', 'det')
# ('high', '31', 'amod')
# ('incidence', '27', 'nmod')
# ('of', '34', 'case')
# ('skin', '34', 'compound')
# ('cancers', '31', 'nmod')
# ('.', '1', 'punct')
# ('We', '2', 'nsubj')
# ('designed', '0', 'root')
# (',', '4', 'punct')
# ('developed', '2', 'conj')
# ('and', '6', 'cc')
# ('assessed', '2', 'conj')
# ('several', '10', 'amod')
# ('complementary', '10', 'amod')
# ('molecular', '10', 'amod')
# ('approaches', '6', 'obj')
# ('to', '12', 'mark')
# ('detect', '10', 'acl')
# ('a', '16', 'det')
# ('genetically', '15', 'advmod')
# ('inherited', '16', 'amod')
# ('deletion', '12', 'obj')
# ('within', '20', 'case')
# ('DNA', '19', 'compound')
# ('polymerase', '20', 'compound')
# ('eta', '16', 'nmod')
# ('.', '2', 'punct')
# ('RNA', '4', 'nsubj:pass')
# ('was', '4', 'aux:pass')
# ('reverse', '4', 'advmod')
# ('transcribed', '0', 'root')
# ('from', '7', 'case')
# ('XPV', '7', 'compound')
# ('fibroblasts', '4', 'obl')
# ('and', '12', 'cc')
# ('from', '12', 'case')
# ('normal', '12', 'amod')
# ('human', '12', 'amod')
# ('cells', '7', 'conj')
# (',', '23', 'punct')
# ('and', '18', 'cc')
# ('standard', '18', 'amod')
# ('polymerase', '17', 'compound')
# ('chain', '18', 'compound')
# ('reaction', '7', 'conj')
# ('(', '20', 'punct')
# ('PCR', '18', 'appos')
# (')', '20', 'punct')
# ('was', '23', 'aux:pass')
# ('conducted', '4', 'conj')
# ('on', '26', 'case')
# ('the', '26', 'det')
# ('cDNA', '23', 'obl')
# ('targeting', '26', 'acl')
# ('a', '29', 'det')
# ('region', '27', 'obj')
# ('with', '35', 'case')
# ('a', '35', 'det')
# ('13', '34', 'nummod')
# ('base', '34', 'compound')
# ('pair', '35', 'compound')
# ('deletion', '27', 'obl')
# ('within', '40', 'case')
# ('the', '40', 'det')
# ('polymerase', '40', 'compound')
# ('eta', '40', 'compound')
# ('gene', '35', 'nmod')
# ('.', '4', 'punct')
# ('PCR', '2', 'compound')
# ('products', '4', 'nsubj:pass')
# ('were', '4', 'aux:pass')
# ('subjected', '0', 'root')
# ('to', '9', 'case')
# ('restriction', '9', 'compound')
# ('fragment', '9', 'compound')
# ('length', '9', 'compound')
# ('polymorphism', '4', 'obl')
# ('(', '11', 'punct')
# ('RFLP', '13', 'compound')
# (')', '11', 'punct')
# ('analysis', '9', 'conj')
# ('and', '17', 'cc')
# ('cycle', '16', 'compound')
# ('DNA', '17', 'compound')
# ('sequencing', '13', 'conj')
# ('.', '4', 'punct')
# ('The', '2', 'det')
# ('deletion', '4', 'nsubj:pass')
# ('was', '4', 'aux:pass')
# ('found', '0', 'root')
# ('to', '6', 'mark')
# ('eliminate', '4', 'xcomp')
# ('a', '10', 'det')
# ('BsrGI', '10', 'compound')
# ('restriction', '10', 'compound')
# ('site', '6', 'obj')
# ('and', '12', 'cc')
# ('affected', '6', 'conj')
# ('the', '14', 'det')
# ('number', '12', 'obj')
# ('of', '17', 'case')
# ('resultant', '17', 'amod')
# ('fragments', '14', 'nmod')
# ('visualized', '17', 'acl')
# ('after', '21', 'case')
# ('gel', '21', 'compound')
# ('electrophoresis', '18', 'obl')
# ('.', '4', 'punct')
# ('Cycle', '2', 'compound')
# ('sequencing', '12', 'nsubj')
# ('of', '6', 'case')
# ('polymerase', '5', 'compound')
# ('eta-specific', '6', 'compound')
# ('amplicons', '2', 'nmod')
# ('from', '8', 'case')
# ('XPV', '6', 'nmod')
# ('and', '11', 'cc')
# ('normal', '11', 'amod')
# ('cells', '8', 'conj')
# ('provided', '0', 'root')
# ('a', '15', 'det')
# ...
# ('in', '18', 'case')
# ('the', '18', 'det')
# ('Aristaless', '13', 'amod')
# ('-', '13', 'punct')
# ('related', '14', 'amod')
# ('homeobox', '18', 'compound')
# ('(', '16', 'punct')
# ('ARX', '14', 'appos')
# (')', '16', 'punct')
# ('gene', '6', 'nmod')
# ('.', '1', 'punct')
# ('ARX', '2', 'compound')
# ('mutations', '3', 'nsubj')
# ('cause', '0', 'root')
# ('a', '6', 'det')
# ('diverse', '6', 'amod')
# ('spectrum', '3', 'obj')
# ('of', '9', 'case')
# ('human', '9', 'amod')
# ('disorders', '6', 'nmod')
# (',', '9', 'punct')
# ('ranging', '9', 'acl')
# ('from', '17', 'case')
# ('severe', '17', 'amod')
# ('brain', '17', 'compound')
# ('and', '16', 'cc')
# ('genital', '14', 'conj')
# ('malformations', '11', 'obl')
# ('to', '21', 'case')
# ('non-syndromic', '21', 'amod')
# ('intellectual', '21', 'amod')
# ('disability', '11', 'obl')
# ('(', '23', 'punct')
# ('ID', '21', 'appos')
# (')', '23', 'punct')
# ('.', '3', 'punct')
# ('ARX', '5', 'nsubj')
# ('is', '5', 'cop')
# ('a', '5', 'det')
# ('transcription', '5', 'compound')
# ('factor', '0', 'root')
# ('with', '8', 'case')
# ('multiple', '8', 'amod')
# ('domains', '5', 'nmod')
# ('that', '10', 'nsubj')
# ('include', '8', 'acl:relcl')
# ('four', '16', 'nummod')
# ('polyalanine', '16', 'amod')
# ('(', '16', 'punct')
# ('pA', '16', 'compound')
# (')', '14', 'punct')
# ('tracts', '10', 'obj')
# (',', '16', 'punct')
# ('the', '20', 'det')
# ('first', '20', 'amod')
# ('two', '25', 'nsubj:pass')
# ('of', '22', 'case')
# ('which', '25', 'obl')
# ('are', '25', 'aux:pass')
# ('frequently', '25', 'advmod')
# ('expanded', '16', 'acl:relcl')
# ('by', '27', 'case')
# ('mutations', '25', 'obl')
# ('.', '5', 'punct')
# ('We', '3', 'nsubj')
# ('progressively', '3', 'advmod')
# ('screened', '0', 'root')
# ('DNA', '5', 'compound')
# ('samples', '3', 'obj')
# ('from', '8', 'case')
# ('613', '8', 'nummod')
# ('individuals', '3', 'obl')
# ('with', '10', 'case')
# ('ID', '8', 'nmod')
# ('initially', '3', 'advmod')
# ('for', '17', 'case')
# ('the', '17', 'det')
# ('most', '15', 'advmod')
# ('frequent', '17', 'amod')
# ('ARX', '17', 'compound')
# ('mutations', '3', 'obl')
# ('(', '19', 'punct')
# ('c.304ins', '17', 'appos')
# ('(', '21', 'punct')
# ('GCG', '19', 'appos')
# (')', '21', 'punct')
# ('(', '24', 'punct')
# ('7', '27', 'nummod')
# (')', '24', 'punct')
# ("'", '27', 'punct')
# ('expansion', '19', 'conj')
# ("'", '27', 'punct')
# ('of', '30', 'case')
# ('pA1', '27', 'nmod')
# ('and', '32', 'cc')
# ('c.', '30', 'conj')
# ('429_452', '32', 'nummod')
# ('dup', '27', 'conj')
# ("'", '37', 'punct')
# ('dup24', '37', 'compound')
# ('bp', '34', 'appos')
# ("'", '37', 'punct')
# ('of', '40', 'case')
# ('pA2', '37', 'nmod')
# (')', '37', 'punct')
# ('.', '3', 'punct')
# ('Five', '2', 'compound')
# ('hundred', '3', 'nummod')
# ('samples', '10', 'nsubj')
# ('without', '5', 'case')
# ('pA1', '3', 'nmod')
# ('or', '9', 'cc')
# ('p', '8', 'compound')
# ('A2', '9', 'compound')
# ('mutations', '5', 'conj')
# ('had', '0', 'root')
# ('the', '14', 'det')
# ('entire', '14', 'amod')
# ('ARX', '14', 'compound')
# ('ORF', '10', 'obj')
# ('screened', '14', 'acl')
# ('by', '20', 'case')
# ('single', '20', 'amod')
# ('stranded', '20', 'amod')
# ('polymorphism', '20', 'compound')
# ('conformation', '15', 'obl')
# ('(', '22', 'punct')
# ('SSCP', '20', 'appos')
# (')', '22', 'punct')
# ('and', '26', 'cc')
# ('/', '26', 'punct')
# ('or', '27', 'cc')
# ('denaturing', '29', 'compound')
# ('high', '29', 'amod')
# ('pressure', '31', 'compound')
# ('liquid', '31', 'compound')
# ('chromatography', '36', 'compound')
# ('(', '34', 'punct')
# ('d', '34', 'compound')
# ('HPLC', '36', 'compound')
# (')', '34', 'punct')
# ('analysis', '15', 'obl')
# ('.', '10', 'punct')
# ('Overall', '11', 'advmod')
# (',', '11', 'punct')
# ('eight', '4', 'nummod')
# ('families', '11', 'nsubj:pass')
# ('with', '7', 'case')
# ('six', '7', 'nummod')
# ('mutations', '4', 'nmod')
# ('in', '9', 'case')
# ('ARX', '7', 'nmod')
# ('were', '11', 'aux:pass')
# ('identified', '0', 'root')
# ('(', '14', 'punct')
# ('1.31', '14', 'nummod')
# ('%', '11', 'appos')
# (')', '14', 'punct')
# (':', '11', 'punct')
# ('five', '19', 'nummod')
# ('duplication', '19', 'compound')
# ('mutations', '11', 'parataxis')
# ('in', '21', 'case')
# ('pA2', '19', 'nmod')
# ('(', '24', 'punct')
#
# ('to', '27', 'case')
# ('unaffected', '27', 'amod')
# ('individuals', '20', 'nmod')
# ('without', '30', 'case')
# ('the', '30', 'det')
# ('deletion', '27', 'nmod')
# ('(', '32', 'punct')
# ('n=', '30', 'appos')
# ('6', '32', 'nummod')
# (')', '32', 'punct')
# ('(', '36', 'punct')
# ('p=', '32', 'appos')
# ('0.002', '36', 'nummod')
# (')', '36', 'punct')
# ('.', '2', 'punct')
# ('TRPV1', '5', 'nsubj')
# ('is', '5', 'cop')
# ('a', '5', 'det')
# ('sensory', '5', 'amod')
# ('receptor', '0', 'root')
# ('located', '5', 'acl')
# ('on', '8', 'case')
# ('chromosome', '6', 'obl')
# ('17p13', '8', 'nummod')
# (',', '6', 'punct')
# ('adjacent', '6', 'advmod')
# ('to', '13', 'case')
# ('CARKL', '6', 'obl')
# ('/', '15', 'cc')
# ('SHPK', '13', 'conj')
# ('.', '5', 'punct')
# ('It', '3', 'nsubj:pass')
# ('was', '3', 'aux:pass')
# ('ascertained', '0', 'root')
# ('that', '9', 'mark')
# ('the', '8', 'det')
# ('57', '8', 'nummod')
# ('kb', '8', 'compound')
# ('deletion', '9', 'nsubj')
# ('extends', '3', 'ccomp')
# ('from', '11', 'case')
# ('exon', '9', 'obl')
# ('10', '9', 'obj')
# ('of', '14', 'case')
# ('CTNS', '12', 'nmod')
# (',', '9', 'punct')
# ('upstream', '12', 'appos')
# ('through', '18', 'case')
# ('CARKL', '16', 'obl')
# ('/', '20', 'cc')
# ('SHPK', '18', 'conj')
# (',', '9', 'punct')
# ('to', '23', 'case')
# ('intron', '9', 'obl')
# ('2', '23', 'nummod')
# ('of', '26', 'case')
# ('TRPV1', '24', 'nmod')
# (',', '9', 'punct')
# ('thus', '29', 'advmod')
# ('deleting', '9', 'advcl')
# ('the', '34', 'det')
# ('first', '34', 'amod')
# ('two', '34', 'nummod')
# ('non-coding', '34', 'amod')
# ('exons', '29', 'obj')
# ('.', '3', 'punct')
# ('CONCLUSION', '0', 'root')
# (':', '1', 'punct')
# ('This', '7', 'nsubj')
# ('is', '7', 'cop')
# ('the', '7', 'det')
# ('first', '7', 'amod')
# ('study', '1', 'appos')
# ('to', '9', 'mark')
# ('report', '7', 'csubj')
# ('that', '15', 'mark')
# ('the', '14', 'det')
# ('57', '14', 'nummod')
# ('kb', '14', 'compound')
# ('deletion', '15', 'nsubj')
# ('extends', '9', 'ccomp')
# ('into', '19', 'case')
# ('the', '19', 'det')
# ('TRPV1', '19', 'compound')
# ('gene', '15', 'obl')
# ('causing', '19', 'acl')
# ('dysregulation', '20', 'obj')
# ('of', '23', 'case')
# ('transcription', '21', 'nmod')
# ('in', '25', 'case')
# ('PBMC', '23', 'nmod')
# ('isolated', '23', 'acl')
# ('from', '29', 'case')
# ('cystinosis', '29', 'compound')
# ('patients', '26', 'obl')
# ('.', '1', 'punct')
# ('Strong', '2', 'amod')
# ('association', '0', 'root')
# ('of', '6', 'case')
# ('677', '6', 'nummod')
# ('C>T', '6', 'compound')
# ('substitution', '2', 'nmod')
# ('in', '10', 'case')
# ('the', '10', 'det')
# ('MTHFR', '10', 'compound')
# ('gene', '2', 'nmod')
# ('with', '13', 'case')
# ('male', '13', 'amod')
# ('infertility', '10', 'nmod')
# ('--', '13', 'punct')
# ('a', '16', 'det')
# ('study', '2', 'appos')
# ('on', '20', 'case')
# ('an', '20', 'det')
# ('indian', '20', 'amod')
# ('population', '16', 'nmod')
# ('and', '23', 'cc')
# ('a', '23', 'det')
# ('meta-analysis', '20', 'conj')
# ('.', '2', 'punct')
# ('BACKGROUND', '0', 'root')
# (':', '1', 'punct')
# ('Methylenetetrahydrofolate', '4', 'compound')
# ('reductase', '11', 'nsubj')
# ('(', '6', 'punct')
# ('MTHFR', '4', 'appos')
# (')', '6', 'punct')
# ('is', '11', 'cop')
# ('an', '11', 'det')
# ('important', '11', 'amod')
# ('enzyme', '1', 'appos')
# ('of', '13', 'case')
# ('folate', '11', 'nmod')
# ('and', '16', 'cc')
# ('methionine', '16', 'compound')
# ('metabolism', '13', 'conj')
# (',', '11', 'punct')
# ('making', '11', 'acl')
# ('it', '18', 'obj')
# ('crucial', '18', 'xcomp')
# ('for', '23', 'case')
# ('DNA', '23', 'compound')
# ('synthesis', '20', 'obl')
# ('and', '25', 'cc')
# ('methylation', '23', 'conj')
# ('.', '1', 'punct')
# ('The', '2', 'det')
# ('objective', '6', 'nsubj')
# ('of', '5', 'case')
# ('this', '5', 'det')
# ('study', '2', 'nmod')
# ('was', '0', 'root')
# ('to', '8', 'mark')
# ('analyze', '6', 'ccomp')
# ('MTHFR', '11', 'compound')
# ('gene', '11', 'compound')
# ('677C', '8', 'obj')
# ('>', '11', 'punct')
# ('T', '2', 'compound')
# ('polymorphism', '0', 'root')
# ('in', '6', 'case')
# ('infertile', '6', 'amod')
# ('male', '6', 'amod')
# ('individuals', '2', 'nmod')
# ('from', '9', 'case')
# ('North', '9', 'compound')
# ('India', '6', 'nmod')
# (',', '2', 'punct')
# ('followed', '2', 'acl')
# ('by', '14', 'case')
# ('a', '14', 'det')
# ('meta-analysis', '11', 'obl')
# ('on', '17', 'case')
# ('our', '17', 'nmod:poss')
# ('data', '14', 'nmod')
# ('and', '19', 'cc')
# ('published', '11', 'conj')
# ('studies', '19', 'obj')
# ('.', '2', 'punct')
# ('METHODOLOGY', '4', 'compound')
# ('/', '3', 'punct')
# ('PRINCIPAL', '1', 'conj')
# ('FINDINGS', '0', 'root')
# (':', '4', 'punct')
# ('We', '2', 'nsubj')
# ('undertook', '0', 'root')
# ('genotyping', '2', 'xcomp')
# ('on', '6', 'case')
# ('a', '6', 'det')
# ('total', '3', 'obl')
# ('of', '9', 'case')
# ('837', '9', 'nummod')
# ('individuals', '6', 'nmod')
# ('including', '13', 'case')
# ('well', '12', 'advmod')
# ('characterized', '13', 'amod')
# ('infertile', '9', 'amod')
# ('(', '15', 'punct')
# ('N', '13', 'appos')
# ('=', '15', 'punct')
# ('522', '15', 'nummod')
# (')', '15', 'punct')
# ('and', '21', 'cc')
# ('confirmed', '21', 'amod')
# ('fertile', '13', 'conj')
# ('(', '23', 'punct')
# ('N', '21', 'appos')
# ('=', '23', 'punct')
# ('315', '23', 'nummod')
# (')', '23', 'punct')
# ('individuals', '21', 'appos')
# ('.', '2', 'punct')
# ('The', '2', 'det')
# ('SNP', '4', 'nsubj:pass')
# ('was', '4', 'aux:pass')
# ('typed', '0', 'root')
# ('by', '8', 'case')
# ('direct', '8', 'amod')
# ('DNA', '8', 'compound')
# ('sequencing', '4', 'obl')
# ('.', '4', 'punct')
# ('Chi', '2', 'compound')
# ('square', '3', 'compound')
# ('test', '5', 'nsubj:pass')
# ('was', '5', 'aux:pass')
# ('done', '0', 'root')
# ('for', '8', 'case')
# ('statistical', '8', 'amod')
# ('analysis', '5', 'obl')
# ('.', '5', 'punct')
# ('Published', '2', 'amod')
# ('studies', '4', 'nsubj:pass')
# ('were', '4', 'aux:pass')
# ('searched', '0', 'root')
# ('using', '4', 'advcl')
# ('appropriate', '7', 'amod')
# ('keywords', '5', 'obj')
# ('.', '4', 'punct')
# ('Source', '0', 'root')
# ('of', '4', 'case')
# ('data', '4', 'compound')
# ('collection', '1', 'nmod')
# ('for', '9', 'case')
# ('meta-analysis', '9', 'amod')
# ('included', '9', 'amod')
# ("'", '9', 'punct')
# ('Pubmed', '1', 'nmod')
# ("'", '9', 'punct')
# (',', '13', 'punct')
# ("'", '13', 'punct')
# ('Ovid', '9', 'appos')
# ("'", '13', 'punct')
# ('and', '18', 'cc')
# ("'", '18', 'punct')
# ('Google', '18', 'compound')
# ('Scholar', '13', 'conj')
# ("'", '18', 'punct')
# ('.', '1', 'punct')
# ('Those', '2', 'det')
# ('studies', '0', 'root')
# ('analyzing', '2', 'acl')
# ('677C', '3', 'obj')
# ('>', '3', 'punct')
# ('T', '2', 'compound')
# ('polymorphism', '12', 'nsubj:pass')
# ('in', '5', 'case')
# ('male', '5', 'amod')
# ('infertility', '2', 'nmod')
# ('and', '7', 'cc')
# ('presenting', '2', 'conj')
# ('all', '10', 'det')
# ('relevant', '10', 'amod')
# ('data', '7', 'obj')
# ('were', '12', 'aux:pass')
# ('included', '0', 'root')
# ('in', '14', 'case')
# ('meta-analysis', '12', 'obl')
# ('.', '12', 'punct')
# ('The', '3', 'det')
# ('genotype', '3', 'compound')
# ('data', '11', 'nsubj:pass')
# ('for', '6', 'case')
# ('infertile', '6', 'amod')
# ('subjects', '3', 'nmod')
# ('and', '9', 'cc')
# ('fertile', '9', 'amod')
# ('controls', '6', 'conj')
# ('was', '11', 'aux:pass')
# ('extracted', '0', 'root')
# ('from', '14', 'case')
# ('each', '14', 'det')
# ('study', '11', 'obl')
# ('.', '11', 'punct')
# ('Chi', '2', 'compound')
# ('square', '3', 'compound')
# ('test', '5', 'nsubj:pass')
# ('was', '5', 'aux:pass')
# ('done', '0', 'root')
# ('to', '7', 'mark')
# ('obtain', '5', 'advcl')
# ('odds', '9', 'compound')
# ('ratio', '7', 'obj')
# ('(', '9', 'punct')
# ('OR', '14', 'cc')
# (')', '9', 'punct')
# ('and', '14', 'cc')
# ('p-value', '9', 'conj')
# ('.', '5', 'punct')
# ('Meta-analysis', '3', 'nsubj:pass')
# ('was', '3', 'aux:pass')
# ('performed', '0', 'root')
# ('using', '3', 'advcl')
# ('Comprehensive', '7', 'amod')
# ('Meta-analysis', '7', 'compound')
# ('software', '4', 'obj')
# ('(', '9', 'punct')
# ('Version', '7', 'appos')
# ('2', '9', 'nummod')
# (')', '9', 'punct')
# ('.', '3', 'punct')
# ('The', '2', 'det')
# ('frequency', '27', 'nsubj')
# ('of', '8', 'case')
# ('mutant', '8', 'compound')
# ('(', '6', 'punct')
# ('T', '8', 'compound')
# (')', '6', 'punct')
# ('allele', '2', 'nmod')
# ('(', '10', 'punct')
# ('p=', '8', 'appos')
# ('0.0025', '10', 'nummod')
# (')', '10', 'punct')
# ('and', '14', 'cc')
# ('genotypes', '8', 'conj')
# ('(', '16', 'punct')
# ('CT', '14', 'appos')
# ('+', '18', 'case')
# ('TT', '16', 'compound')
# (')', '16', 'punct')
# ('(', '21', 'punct')
# ('p', '8', 'appos')
# ('=', '21', 'punct')
# ('0.0187', '21', 'nummod')
# (')', '21', 'punct')
# ('was', '27', 'cop')
# ('significantly', '27', 'advmod')
# ('higher', '0', 'root')
# ('in', '30', 'case')
# ('infertile', '30', 'amod')
# ('individuals', '27', 'obl')
# ('in', '32', 'case')
# ('comparison', '27', 'obl')
# ('to', '35', 'case')
# ('fertile', '35', 'amod')
# ('controls', '32', 'nmod')
# ('in', '41', 'case')
# ('our', '41', 'nmod:poss')
# ('case', '40', 'compound')
# ('-', '40', 'punct')
# ('control', '41', 'compound')
# ('study', '35', 'nmod')
# ('.', '27', 'punct')
# ('The', '4', 'det')
# ('overall', '4', 'amod')
# ('summary', '4', 'compound')
# ('estimate', '14', 'nsubj')
# ('(', '4', 'punct')
# ('OR', '7', 'cc')
# (')', '4', 'punct')
# ('for', '9', 'case')
# ('allele', '4', 'nmod')
# ('and', '12', 'cc')
# ('genotype', '12', 'compound')
# ('meta-analysis', '9', 'conj')
# ('were', '14', 'cop')
# ('1.304', '0', 'root')
# ('(', '16', 'punct')
# ('p=', '14', 'appos')
# ('0.000', '16', 'nummod')
# (')', '16', 'punct')
# (',', '16', 'punct')
# ('1.310', '16', 'nummod')
# ('(', '22', 'punct')
# ('p', '14', 'appos')
# ('=', '22', 'punct')
# ('0.000', '22', 'nummod')
# (')', '22', 'punct')
# (',', '22', 'punct')
# ('respectively', '29', 'advmod')
# (',', '29', 'punct')
# ('establishing', '14', 'advcl')
# ('significant', '31', 'amod')
# ('association', '29', 'obj')
# ('of', '33', 'case')
# ('677C', '31', 'nmod')
# ('>', '29', 'punct')
# ('T', '2', 'compound')
# ('polymorphism', '0', 'root')
# ('with', '5', 'case')
# ('male', '5', 'amod')
# ('infertility', '2', 'nmod')
# ('.', '2', 'punct')
# ('CONCLUSIONS', '0', 'root')
# ('/', '3', 'cc')
# ('SIGNIFICANCE', '1', 'conj')
# (':', '1', 'punct')
# ('677C', '3', 'appos')
# ('>', '3', 'punct')
# ('T', '2', 'compound')
# ('substitution', '0', 'root')
# ('associated', '2', 'acl')
# ('strongly', '3', 'advmod')
# ('with', '7', 'case')
# ('male', '7', 'amod')
# ('infertility', '3', 'obl')
# ('in', '10', 'case')
# ('Indian', '10', 'amod')
# ('population', '3', 'obl')
# ('.', '2', 'punct')
# ('Allele', '6', 'nsubj')
# ('and', '3', 'cc')
# ('genotype', '1', 'conj')
# ('meta-analysis', '1', 'advmod')
# ('also', '6', 'advmod')
# ('supported', '0', 'root')
# ('its', '9', 'nmod:poss')
# ('strong', '9', 'amod')
# ('correlation', '6', 'obj')
# ('with', '12', 'case')
# ('male', '12', 'amod')
# ('infertility', '9', 'nmod')
# (',', '6', 'punct')
# ('thus', '15', 'advmod')
# ('establishing', '6', 'advcl')
# ('it', '15', 'obj')
# ('as', '20', 'case')
# ('a', '20', 'det')
# ('risk', '20', 'compound')
# ('factor', '15', 'obl')
# ('.', '6', 'punct')
# ('Angiotensin', '3', 'obl:npmod')
# ('-', '3', 'punct')
# ('converting', '4', 'compound')
# ('enzyme', '0', 'root')
# ('(', '6', 'punct')
# ('ACE', '4', 'appos')
# (')', '6', 'punct')
# ('serum', '9', 'compound')
# ('levels', '4', 'conj')
# ('and', '12', 'cc')
# ('gene', '12', 'compound')
# ('polymorphism', '4', 'conj')
# ('in', '15', 'case')
# ('Egyptian', '15', 'amod')
# ('patients', '4', 'nmod')
# ('with', '19', 'case')
# ('systemic', '19', 'amod')
# ('lupus', '19', 'amod')
# ('erythematosus', '15', 'nmod')
# ('.', '4', 'punct')
# ('OBJECTIVES', '0', 'root')
# (':', '1', 'punct')
# ('To', '2', 'mark')
# ('investigate', '0', 'root')
# ('the', '4', 'det')
# ('association', '2', 'obj')
# ('of', '14', 'case')
# ('angiotensin', '8', 'compound')
# ('-', '8', 'punct')
# ('converting', '9', 'compound')
# ('enzyme', '14', 'compound')
# ('(', '11', 'punct')
# ('ACE', '14', 'compound')
# (')', '11', 'punct')
# ('gene', '14', 'compound')
# ('polymorphism', '4', 'nmod')
# ('and', '18', 'cc')
# ('serum', '17', 'compound')
# ('ACE', '18', 'compound')
# ('level', '14', 'conj')
# ('among', '22', 'case')
# ('Egyptian', '22', 'amod')
# ('SLE', '22', 'amod')
# ('patients', '14', 'nmod')
# ('and', '25', 'cc')
# ('its', '25', 'nmod:poss')
# ('relation', '14', 'conj')
# ('to', '29', 'case')
# ('disease', '28', 'compound')
# ('activity', '29', 'compound')
# ('parameters', '25', 'nmod')
# ('.', '2', 'punct')
# ('SUBJECTS', '0', 'root')
# ('AND', '3', 'cc')
# ('METHODS', '1', 'conj')
# (':', '1', 'punct')
# ('We', '2', 'nsubj')
# ('enrolled', '0', 'root')
# ('50', '8', 'nummod')
# ('Egyptian', '8', 'amod')

# %%
def lemmatize(doc):

    parsed_text = {'word': [], 'lemma': []}
    for sent in doc.sentences:
        for wrd in sent.words:
            # extract text and lemma
            parsed_text['word'].append(wrd.text)
            parsed_text['lemma'].append(wrd.lemma)
    # return a dataframe
    return pd.DataFrame(parsed_text)

# %%
lemma = lemmatize(doc)

# %%
print(lemma)
# Out:
#                 word           lemma
# 0                  A               a
# 1              novel           novel
# 2           missense        missense
# 3           mutation        mutation
# 4                Asp             asp
# 5                506             506
# 6                Gly             Gly
# 7                 in              in
# 8               Exon            Exon
# 9                 13              13
# 10                of              of
# 11               the             the
# 12               F11             F11
# 13              gene            gene
# 14                in              in
# 15                an               a
# 16      asymptomatic    asymptomatic
# 17            Korean          Korean
# 18             woman           woman
# 19              with            with
# 20              mild            mild
# 21            factor          factor
# 22                XI              XI
# 23        deficiency      deficiency
# 24                 .               .
# 25            Factor          factor
# 26                XI              XI
# 27                 (               (
# 28               FXI             FXI
# 29                 )               )
# ...              ...             ...
# 6724            gene            gene
# 6725             and             and
# 6726           amino           amino
# 6727            acid            acid
# 6728    substitution    substitution
# 6729              at              at
# 6730        position        position
# 6731              70              70
# 6732              in              in
# 6733             the             the
# 6734            core            core
# 6735          region          region
# 6736              of              of
# 6737             the             the
# 6738       hepatitis       hepatitis
# 6739               C               c
# 6740           virus           virus
# 6741             are              be
# 6742    determinants     determinant
# 6743              of              of
# 6744           serum           serum
# 6745  apolipoprotein  apolipoprotein
# 6746               B               b
# 6747               -               -
# 6748             100             100
# 6749   concentration   concentration
# 6750              in              in
# 6751         chronic         chronic
# 6752       hepatitis       hepatitis
# 6753              C.              C.
#
# [6754 rows x 2 columns]

# %%
#dictionary that contains pos tags and their explanations
pos_dict = {
'CC': 'coordinating conjunction','CD': 'cardinal digit','DT': 'determiner',
'EX': 'existential there (like: \"there is\" ... think of it like \"there exists\")',
'FW': 'foreign word','IN':  'preposition/subordinating conjunction','JJ': 'adjective \'big\'',
'JJR': 'adjective, comparative \'bigger\'','JJS': 'adjective, superlative \'biggest\'',
'LS': 'list marker 1)','MD': 'modal could, will','NN': 'noun, singular \'desk\'',
'NNS': 'noun plural \'desks\'','NNP': 'proper noun, singular \'Harrison\'',
'NNPS': 'proper noun, plural \'Americans\'','PDT': 'predeterminer \'all the kids\'',
'POS': 'possessive ending parent\'s','PRP': 'personal pronoun I, he, she',
'PRP$': 'possessive pronoun my, his, hers','RB': 'adverb very, silently,',
'RBR': 'adverb, comparative better','RBS': 'adverb, superlative best',
'RP': 'particle give up','TO': 'to go \'to\' the store.','UH': 'interjection errrrrrrrm',
'VB': 'verb, base form take','VBD': 'verb, past tense took',
'VBG': 'verb, gerund/present participle taking','VBN': 'verb, past participle taken',
'VBP': 'verb, sing. present, non-3d take','VBZ': 'verb, 3rd person sing. present takes',
'WDT': 'wh-determiner which','WP': 'wh-pronoun who, what','WP$': 'possessive wh-pronoun whose',
'WRB': 'wh-abverb where, when','QF' : 'quantifier, bahut, thoda, kam (Hindi)','VM' : 'main verb',
'PSP' : 'postposition, common in indian langs','DEM' : 'demonstrative, common in indian langs'
}

# %%
#extract parts of speech
def extract_pos(doc):
    parsed_text = {'word':[], 'pos':[], 'exp':[]}
    for sent in doc.sentences:
        for wrd in sent.words:
            if wrd.pos in pos_dict.keys():
                pos_exp = pos_dict[wrd.pos]
            else:
                pos_exp = 'NA'
            parsed_text['word'].append(wrd.text)
            parsed_text['pos'].append(wrd.pos)
            parsed_text['exp'].append(pos_exp)
    #return a dataframe of pos and text
    return pd.DataFrame(parsed_text)

# %%
print(extract_pos(doc))
# Out:
#                 word    pos                                    exp
# 0                  A     DT                             determiner
# 1              novel     NN                  noun, singular 'desk'
# 2           missense     NN                  noun, singular 'desk'
# 3           mutation     NN                  noun, singular 'desk'
# 4                Asp     NN                  noun, singular 'desk'
# 5                506     CD                         cardinal digit
# 6                Gly    NNP       proper noun, singular 'Harrison'
# 7                 in     IN  preposition/subordinating conjunction
# 8               Exon    NNP       proper noun, singular 'Harrison'
# 9                 13     CD                         cardinal digit
# 10                of     IN  preposition/subordinating conjunction
# 11               the     DT                             determiner
# 12               F11    NNP       proper noun, singular 'Harrison'
# 13              gene     NN                  noun, singular 'desk'
# 14                in     IN  preposition/subordinating conjunction
# 15                an     DT                             determiner
# 16      asymptomatic     JJ                        adjective 'big'
# 17            Korean     JJ                        adjective 'big'
# 18             woman     NN                  noun, singular 'desk'
# 19              with     IN  preposition/subordinating conjunction
# 20              mild     JJ                        adjective 'big'
# 21            factor     NN                  noun, singular 'desk'
# 22                XI     NN                  noun, singular 'desk'
# 23        deficiency     NN                  noun, singular 'desk'
# 24                 .      .                                     NA
# 25            Factor     NN                  noun, singular 'desk'
# 26                XI     NN                  noun, singular 'desk'
# 27                 (  -LRB-                                     NA
# 28               FXI    NNP       proper noun, singular 'Harrison'
# 29                 )  -RRB-                                     NA
# ...              ...    ...                                    ...
# 6724            gene     NN                  noun, singular 'desk'
# 6725             and     CC               coordinating conjunction
# 6726           amino     NN                  noun, singular 'desk'
# 6727            acid     NN                  noun, singular 'desk'
# 6728    substitution     NN                  noun, singular 'desk'
# 6729              at     IN  preposition/subordinating conjunction
# 6730        position     NN                  noun, singular 'desk'
# 6731              70     CD                         cardinal digit
# 6732              in     IN  preposition/subordinating conjunction
# 6733             the     DT                             determiner
# 6734            core     JJ                        adjective 'big'
# 6735          region     NN                  noun, singular 'desk'
# 6736              of     IN  preposition/subordinating conjunction
# 6737             the     DT                             determiner
# 6738       hepatitis     NN                  noun, singular 'desk'
# 6739               C     NN                  noun, singular 'desk'
# 6740           virus     NN                  noun, singular 'desk'
# 6741             are    VBP       verb, sing. present, non-3d take
# 6742    determinants    NNS                    noun plural 'desks'
# 6743              of     IN  preposition/subordinating conjunction
# 6744           serum     NN                  noun, singular 'desk'
# 6745  apolipoprotein     NN                  noun, singular 'desk'
# 6746               B     NN                  noun, singular 'desk'
# 6747               -   HYPH                                     NA
# 6748             100     CD                         cardinal digit
# 6749   concentration     NN                  noun, singular 'desk'
# 6750              in     IN  preposition/subordinating conjunction
# 6751         chronic     JJ                        adjective 'big'
# 6752       hepatitis     NN                  noun, singular 'desk'
# 6753              C.     NN                  noun, singular 'desk'
#
# [6754 rows x 3 columns]
